# %% [markdown]
# # Import Library

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import tensorflow as tf
import matplotlib.pyplot as plt

# %% [markdown]
# # Membaca Dataset

# %%
df_rating = pd.read_csv('data/tourism_rating.csv')
df_wisata = pd.read_csv('data/tourism_with_id.csv')

# %%
# menampilkan 5 data teratas

df_rating.head()
# Out:
#    IdUser  IdWisata  rating
# 0        1       179              3
# 1        1       344              2
# 2        1         5              5
# 3        1       373              3
# 4        1       101              4

# %%
# menampilkan 5 data teratas

df_wisata.head()
# Out:
#    IdWisata                         Place_Name  \
# 0         1                   Monumen Nasional
# 1         2                           Kota Tua
# 2         3                      Dunia Fantasi
# 3         4  Taman Mini Indonesia Indah (TMII)
# 4         5           Atlantis Water Adventure
#
#                                          Description       Category     City  \
# 0  Monumen Nasional atau yang populer disingkat d...         Budaya  Jakarta
# 1  Kota tua di Jakarta, yang juga bernama Kota Tu...         Budaya  Jakarta
# 2  Dunia Fantasi atau disebut juga Dufan adalah t...  Taman Hiburan  Jakarta
# 3  Taman Mini Indonesia Indah merupakan suatu kaw...  Taman Hiburan  Jakarta
# 4  Atlantis Water Adventure atau dikenal dengan A...  Taman Hiburan  Jakarta
#
#     Price  Rating  Time_Minutes  \
# 0   20000     4.6          15.0
# 1       0     4.6          90.0
# 2  270000     4.6         360.0
# 3   10000     4.5           NaN
# 4   94000     4.5          60.0
#
#                                         Coordinate       Lat        Long  \
# 0          {'lat': -6.1753924, 'lng': 106.8271528} -6.175392  106.827153
# 1  {'lat': -6.137644799999999, 'lng': 106.8171245} -6.137645  106.817125
# 2  {'lat': -6.125312399999999, 'lng': 106.8335377} -6.125312  106.833538
# 3  {'lat': -6.302445899999999, 'lng': 106.8951559} -6.302446  106.895156
# 4             {'lat': -6.12419, 'lng': 106.839134} -6.124190  106.839134
#
#    Unnamed: 11  Unnamed: 12
# 0          NaN            1
# 1          NaN            2
# 2          NaN            3
# 3          NaN            4
# 4          NaN            5

# %%
# membuang kolom yang tidak diperlukan

df_wisata.drop(['Unnamed: 11', 'Unnamed: 12', 'Lat', 'Long', 'Coordinate', 'Time_Minutes'], axis=1, inplace=True)

# %%
df_wisata.head()
# Out:
#    IdWisata                         Place_Name  \
# 0         1                   Monumen Nasional
# 1         2                           Kota Tua
# 2         3                      Dunia Fantasi
# 3         4  Taman Mini Indonesia Indah (TMII)
# 4         5           Atlantis Water Adventure
#
#                                          Description       Category     City  \
# 0  Monumen Nasional atau yang populer disingkat d...         Budaya  Jakarta
# 1  Kota tua di Jakarta, yang juga bernama Kota Tu...         Budaya  Jakarta
# 2  Dunia Fantasi atau disebut juga Dufan adalah t...  Taman Hiburan  Jakarta
# 3  Taman Mini Indonesia Indah merupakan suatu kaw...  Taman Hiburan  Jakarta
# 4  Atlantis Water Adventure atau dikenal dengan A...  Taman Hiburan  Jakarta
#
#     Price  Rating
# 0   20000     4.6
# 1       0     4.6
# 2  270000     4.6
# 3   10000     4.5
# 4   94000     4.5

# %%
# memilih hanya kota Yogyakarta saja

df_wisata = df_wisata[df_wisata['City'] == 'Yogyakarta']

# %% [markdown]
# # Exploratory Data Analysis

# %%
# menggabungkan kedua dataframe

df = pd.merge(df_rating, df_wisata, on='IdWisata')

df.head(10)
# Out:
#    IdUser  IdWisata  rating       Place_Name  \
# 0        1       179              3  Candi Ratu Boko
# 1       22       179              4  Candi Ratu Boko
# 2       40       179              3  Candi Ratu Boko
# 3       49       179              5  Candi Ratu Boko
# 4       74       179              3  Candi Ratu Boko
# 5       76       179              1  Candi Ratu Boko
# 6       84       179              4  Candi Ratu Boko
# 7      127       179              4  Candi Ratu Boko
# 8      127       179              3  Candi Ratu Boko
# 9      134       179              2  Candi Ratu Boko
#
#                                          Description Category        City  \
# 0  Situs Ratu Baka atau Candi Boko (Hanacaraka:ꦕꦤ...   Budaya  Yogyakarta
# 1  Situs Ratu Baka atau Candi Boko (Hanacaraka:ꦕꦤ...   Budaya  Yogyakarta
# 2  Situs Ratu Baka atau Candi Boko (Hanacaraka:ꦕꦤ...   Budaya  Yogyakarta
# 3  Situs Ratu Baka atau Candi Boko (Hanacaraka:ꦕꦤ...   Budaya  Yogyakarta
# 4  Situs Ratu Baka atau Candi Boko (Hanacaraka:ꦕꦤ...   Budaya  Yogyakarta
# 5  Situs Ratu Baka atau Candi Boko (Hanacaraka:ꦕꦤ...   Budaya  Yogyakarta
# 6  Situs Ratu Baka atau Candi Boko (Hanacaraka:ꦕꦤ...   Budaya  Yogyakarta
# 7  Situs Ratu Baka atau Candi Boko (Hanacaraka:ꦕꦤ...   Budaya  Yogyakarta
# 8  Situs Ratu Baka atau Candi Boko (Hanacaraka:ꦕꦤ...   Budaya  Yogyakarta
# 9  Situs Ratu Baka atau Candi Boko (Hanacaraka:ꦕꦤ...   Budaya  Yogyakarta
#
#    Price  Rating
# 0  75000     4.6
# 1  75000     4.6
# 2  75000     4.6
# 3  75000     4.6
# 4  75000     4.6
# 5  75000     4.6
# 6  75000     4.6
# 7  75000     4.6
# 8  75000     4.6
# 9  75000     4.6

# %%
# menampilkan informasi pada data yang sudah digabungkan

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2871 entries, 0 to 2870
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   IdUser        2871 non-null   int64
#  1   IdWisata       2871 non-null   int64
#  2   rating  2871 non-null   int64
#  3   Place_Name     2871 non-null   object
#  4   Description    2871 non-null   object
#  5   Category       2871 non-null   object
#  6   City           2871 non-null   object
#  7   Price          2871 non-null   int64
#  8   Rating         2871 non-null   float64
# dtypes: float64(1), int64(4), object(4)
# memory usage: 224.3+ KB

# %%
# Melihat nilai null pada data

df.isnull().sum()
# Out:
# IdUser          0
# IdWisata         0
# rating    0
# Place_Name       0
# Description      0
# Category         0
# City             0
# Price            0
# Rating           0
# dtype: int64

# %%
# Melihat data unique pada kolom rating,price,dan kategori

print("Data unik pada data rating: ", df['Rating'].unique())

print("Data unik pada data price: ", df['Price'].unique())

print("Data unik pada data kategori: ", df['Category'].unique())
# Out:
# Data unik pada data rating:  [4.6 4.  4.5 4.7 4.4 4.3 5.  4.1 4.2 4.8]
# Data unik pada data price:  [ 75000      0  10000  50000   6000   3000   5000  15000  20000   2500
#    2000   4000  40000 150000   8000   7000  30000  25000 220000  60000
#  500000 250000  22000 100000]
# Data unik pada data kategori:  ['Budaya' 'Bahari' 'Taman Hiburan' 'Cagar Alam' 'Pusat Perbelanjaan']

# %%
# see count of each price

df['Price'].value_counts()

# sort the price

df['Price'].value_counts().sort_index()
# Out:
# 0         579
# 2000       63
# 2500      108
# 3000      181
# 4000       47
# 5000      510
# 6000       46
# 7000       44
# 8000       22
# 10000     621
# 15000     133
# 20000     105
# 22000      21
# 25000      17
# 30000      31
# 40000      73
# 50000     113
# 60000      24
# 75000      24
# 100000     12
# 150000     29
# 220000     22
# 250000     25
# 500000     21
# Name: Price, dtype: int64

# %%
"""
I want to normalize df['Rating'] data so that the value is between 0 until 5 because the rating value is between 0 until 5. 

I want to change the label become like this:

4.0 , 4.1 ==> 1,
4.2, 4.3 ==> 2,
4.4, 4.5 ==> 3,
4.6, 4.7 ==> 4,
4.8, 4.9, 5.0 ==> 5
"""

# change the label

df['Rating'] = df['Rating'].replace([4.0, 4.1], 0)
df['Rating'] = df['Rating'].replace([4.2, 4.3], 1)
df['Rating'] = df['Rating'].replace([4.4, 4.5], 2)
df['Rating'] = df['Rating'].replace([4.6, 4.7], 3)
df['Rating'] = df['Rating'].replace([4.8, 4.9, 5.0], 4)


# convert data to int

df["Rating"] = df["Rating"].astype(int)

df
# Out:
#       IdUser  IdWisata  rating       Place_Name  \
# 0           1       179              3  Candi Ratu Boko
# 1          22       179              4  Candi Ratu Boko
# 2          40       179              3  Candi Ratu Boko
# 3          49       179              5  Candi Ratu Boko
# 4          74       179              3  Candi Ratu Boko
# ...       ...       ...            ...              ...
# 2866      240       140              3    Bendung Lepen
# 2867      247       140              4    Bendung Lepen
# 2868      261       140              4    Bendung Lepen
# 2869      267       140              3    Bendung Lepen
# 2870      268       140              2    Bendung Lepen
#
#                                             Description       Category  \
# 0     Situs Ratu Baka atau Candi Boko (Hanacaraka:ꦕꦤ...         Budaya
# 1     Situs Ratu Baka atau Candi Boko (Hanacaraka:ꦕꦤ...         Budaya
# 2     Situs Ratu Baka atau Candi Boko (Hanacaraka:ꦕꦤ...         Budaya
# 3     Situs Ratu Baka atau Candi Boko (Hanacaraka:ꦕꦤ...         Budaya
# 4     Situs Ratu Baka atau Candi Boko (Hanacaraka:ꦕꦤ...         Budaya
# ...                                                 ...            ...
# 2866  Bendung Lepen sendiri dulunya merupakan salura...  Taman Hiburan
# 2867  Bendung Lepen sendiri dulunya merupakan salura...  Taman Hiburan
# 2868  Bendung Lepen sendiri dulunya merupakan salura...  Taman Hiburan
# 2869  Bendung Lepen sendiri dulunya merupakan salura...  Taman Hiburan
# 2870  Bendung Lepen sendiri dulunya merupakan salura...  Taman Hiburan
#
#             City  Price  Rating
# 0     Yogyakarta  75000       3
# 1     Yogyakarta  75000       3
# 2     Yogyakarta  75000       3
# 3     Yogyakarta  75000       3
# 4     Yogyakarta  75000       3
# ...          ...    ...     ...
# 2866  Yogyakarta      0       3
# 2867  Yogyakarta      0       3
# 2868  Yogyakarta      0       3
# 2869  Yogyakarta      0       3
# 2870  Yogyakarta      0       3
#
# [2871 rows x 9 columns]

# %%
# Memvisualisasikan data rating dengan menggunakan histogram dan boxplot untuk melihat persebaran data dan pencilan data pada kolom rating 

plt.figure(figsize=(10, 5))
plt.subplot(1, 2, 1)
sns.distplot(df['Rating'])
plt.subplot(1, 2, 2)
sns.boxplot(df['Rating'])
plt.show()
# Out:
# /home/abdulhafidh/anaconda3/envs/tf210/lib/python3.7/site-packages/ipykernel_launcher.py:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   """

# %%
# Memvisualisasikan data price dengan menggunakan histogram dan boxplot untuk melihat persebaran data dan pencilan data pada kolom price

plt.figure(figsize=(10, 5))
plt.subplot(1, 2, 1)
sns.distplot(df['Price'])
plt.subplot(1, 2, 2)
sns.boxplot(df['Price'])

plt.show()
# Out:
# /home/abdulhafidh/anaconda3/envs/tf210/lib/python3.7/site-packages/ipykernel_launcher.py:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   """

# %% [markdown]
# # Data Preprocessing

# %%
# Membuat pemodelan dengan kolom Category, Rating, dan Price 

df_model = df[['Category', 'Rating', 'Price']]

df_model.head()
# Out:
#   Category  Rating  Price
# 0   Budaya       3  75000
# 1   Budaya       3  75000
# 2   Budaya       3  75000
# 3   Budaya       3  75000
# 4   Budaya       3  75000

# %%
# Membuat rentang harga untuk memudahkan dalam proses pemodelan 

# harga 0 - 3000 dilabel menjadi 0 dst

df_model['Price'] = df_model['Price'].replace(range(0, 3000), 0)



df_model['Price'] = df_model['Price'].replace(range(4000, 7000), 1)


df_model['Price'] = df_model['Price'].replace(range(8000, 20000), 2)


df_model['Price'] = df_model['Price'].replace(range(22000, 400000), 3)



df_model['Price'] = df_model['Price'].replace(range(50000, 100000), 4)



df_model['Price'] = df_model['Price'].replace(range(150000, 500000), 5)
# Out:
# /home/abdulhafidh/anaconda3/envs/tf210/lib/python3.7/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """
# /home/abdulhafidh/anaconda3/envs/tf210/lib/python3.7/site-packages/ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if __name__ == "__main__":
# /home/abdulhafidh/anaconda3/envs/tf210/lib/python3.7/site-packages/ipykernel_launcher.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if sys.path[0] == "":
# /home/abdulhafidh/anaconda3/envs/tf210/lib/python3.7/site-packages/ipykernel_launcher.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   from ipykernel import kernelapp as app
# /home/abdulhafidh/anaconda3/envs/tf210/lib/python3.7/site-packages/ipykernel_launcher.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /home/abdulhafidh/anaconda3/envs/tf210/lib/python3.7/site-packages/ipykernel_launcher.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
"""
I want to normalize df['Rating'] data so that the value is between 0 until 5 because the rating value is between 0 until 5. 

I want to change the label become like this:

4.0 , 4.1 ==> 1,
4.2, 4.3 ==> 2,
4.4, 4.5 ==> 3,
4.6, 4.7 ==> 4,
4.8, 4.9, 5.0 ==> 5
"""

# change the label

df_model['Rating'] = df_model['Rating'].replace([4.0, 4.1], 0)
df_model['Rating'] = df_model['Rating'].replace([4.2, 4.3], 1)
df_model['Rating'] = df_model['Rating'].replace([4.4, 4.5], 2)
df_model['Rating'] = df_model['Rating'].replace([4.6, 4.7], 3)
df_model['Rating'] = df_model['Rating'].replace([4.8, 4.9, 5.0], 4)


# convert data to int

df_model["Rating"] = df_model["Rating"].astype(int)

df_model
# Out:
# /home/abdulhafidh/anaconda3/envs/tf210/lib/python3.7/site-packages/ipykernel_launcher.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   from ipykernel import kernelapp as app
# /home/abdulhafidh/anaconda3/envs/tf210/lib/python3.7/site-packages/ipykernel_launcher.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /home/abdulhafidh/anaconda3/envs/tf210/lib/python3.7/site-packages/ipykernel_launcher.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   app.launch_new_instance()
# /home/abdulhafidh/anaconda3/envs/tf210/lib/python3.7/site-packages/ipykernel_launcher.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /home/abdulhafidh/anaconda3/envs/tf210/lib/python3.7/site-packages/ipykernel_launcher.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /home/abdulhafidh/anaconda3/envs/tf210/lib/python3.7/site-packages/ipykernel_launcher.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#            Category  Rating  Price
# 0            Budaya       3      3
# 1            Budaya       3      3
# 2            Budaya       3      3
# 3            Budaya       3      3
# 4            Budaya       3      3
# ...             ...     ...    ...
# 2866  Taman Hiburan       3      0
# 2867  Taman Hiburan       3      0
# 2868  Taman Hiburan       3      0
# 2869  Taman Hiburan       3      0
# 2870  Taman Hiburan       3      0
#
# [2871 rows x 3 columns]

# %%
# Melakukan label encoding pada kolom Category

from sklearn.preprocessing import LabelEncoder

label_encoder = LabelEncoder()

df_model['Category'] = label_encoder.fit_transform(df_model['Category'])

df_model.head()
# Out:
# /home/abdulhafidh/anaconda3/envs/tf210/lib/python3.7/site-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys
#    Category  Rating  Price
# 0         1       3      3
# 1         1       3      3
# 2         1       3      3
# 3         1       3      3
# 4         1       3      3

# %%
# see category unique

print("Data unik pada data kategori: ", df['Category'].unique())

# print data untuk kategori  cagar alam

df[df['Category'] == "Pusat Perbelanjaan"]
# Out:
# Data unik pada data kategori:  ['Budaya' 'Bahari' 'Taman Hiburan' 'Cagar Alam' 'Pusat Perbelanjaan']
#       IdUser  IdWisata  rating                   Place_Name  \
# 2312       22       135              3  Kawasan Wisata Sosrowijayan
# 2313       44       135              3  Kawasan Wisata Sosrowijayan
# 2314       53       135              5  Kawasan Wisata Sosrowijayan
# 2315       54       135              2  Kawasan Wisata Sosrowijayan
# 2316       57       135              4  Kawasan Wisata Sosrowijayan
# ...       ...       ...            ...                          ...
# 2568      276       174              1            Pasar Beringharjo
# 2569      277       174              1            Pasar Beringharjo
# 2570      283       174              2            Pasar Beringharjo
# 2571      288       174              2            Pasar Beringharjo
# 2572      296       174              2            Pasar Beringharjo
#
#                                             Description            Category  \
# 2312  Tempat wisata Sosrowijayan memang selama ini d...  Pusat Perbelanjaan
# 2313  Tempat wisata Sosrowijayan memang selama ini d...  Pusat Perbelanjaan
# 2314  Tempat wisata Sosrowijayan memang selama ini d...  Pusat Perbelanjaan
# 2315  Tempat wisata Sosrowijayan memang selama ini d...  Pusat Perbelanjaan
# 2316  Tempat wisata Sosrowijayan memang selama ini d...  Pusat Perbelanjaan
# ...                                                 ...                 ...
# 2568  Pasar Beringharjo (bahasa Jawa: ꦥꦱꦂꦧꦼꦫꦶꦁꦲꦂꦗ, t...  Pusat Perbelanjaan
# 2569  Pasar Beringharjo (bahasa Jawa: ꦥꦱꦂꦧꦼꦫꦶꦁꦲꦂꦗ, t...  Pusat Perbelanjaan
# 2570  Pasar Beringharjo (bahasa Jawa: ꦥꦱꦂꦧꦼꦫꦶꦁꦲꦂꦗ, t...  Pusat Perbelanjaan
# 2571  Pasar Beringharjo (bahasa Jawa: ꦥꦱꦂꦧꦼꦫꦶꦁꦲꦂꦗ, t...  Pusat Perbelanjaan
# 2572  Pasar Beringharjo (bahasa Jawa: ꦥꦱꦂꦧꦼꦫꦶꦁꦲꦂꦗ, t...  Pusat Perbelanjaan
#
#             City  Price  Rating
# 2312  Yogyakarta      0       0
# 2313  Yogyakarta      0       0
# 2314  Yogyakarta      0       0
# 2315  Yogyakarta      0       0
# 2316  Yogyakarta      0       0
# ...          ...    ...     ...
# 2568  Yogyakarta      0       2
# 2569  Yogyakarta      0       2
# 2570  Yogyakarta      0       2
# 2571  Yogyakarta      0       2
# 2572  Yogyakarta      0       2
#
# [77 rows x 9 columns]

# %%
df_model.iloc[2316]
# Out:
# Category    3
# Rating      0
# Price       0
# Name: 2316, dtype: int64

# %%
# Memilih rating sebagai target dan sisanya sebagai fitur

X = df_model.drop('Rating', axis=1)

y = df_model['Rating']

# %%
# Membagi data menjadi data training dan data testing dengan test size 20% dan random state 0

from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=.2, random_state=42)

# %% [markdown]
# # Melatih Model

# %%
# Membuat model machine learning dengan menggunakan algoritma deep learning yaitu neural network menggunakan tensorflow

model = tf.keras.models.Sequential([

    tf.keras.layers.Dense(128, activation='relu', input_shape=(X_train.shape[1],)),

    tf.keras.layers.Dense(64, activation='relu'),

    tf.keras.layers.Dense(32, activation='relu'),

    # karena ini merupakan masalah klasifikasi multiclass maka pada layer output menggunakan activation softmax dan class nya ada 5 

    tf.keras.layers.Dense(6, activation='softmax')

])

# Menggunakan optimizer adam dan loss function serta menggunakan metrics accuracy

# mengeset learning rate menjadi 0.001

optimizer = tf.keras.optimizers.Adam(0.001)

loss = tf.keras.losses.SparseCategoricalCrossentropy()


model.compile(optimizer=optimizer, loss=loss, metrics=['accuracy'])

# melihat summary dari model yang telah dibuat
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 128)               384
# _________________________________________________________________
# dense_1 (Dense)              (None, 64)                8256
# _________________________________________________________________
# dense_2 (Dense)              (None, 32)                2080
# _________________________________________________________________
# dense_3 (Dense)              (None, 6)                 198
# =================================================================
# Total params: 10,918
# Trainable params: 10,918
# Non-trainable params: 0
# _________________________________________________________________
# 2023-06-11 20:08:12.103048: W tensorflow/stream_executor/platform/default/dso_loader.cc:55] Could not load dynamic library 'libcuda.so.1'; dlerror: libcuda.so.1: cannot open shared object file: No such file or directory
# 2023-06-11 20:08:12.103103: E tensorflow/stream_executor/cuda/cuda_driver.cc:313] failed call to cuInit: UNKNOWN ERROR (303)
# 2023-06-11 20:08:12.103143: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (abdulhafidh): /proc/driver/nvidia/version does not exist
# 2023-06-11 20:08:12.103697: I tensorflow/core/platform/cpu_feature_guard.cc:143] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2 FMA
# 2023-06-11 20:08:12.122299: I tensorflow/core/platform/profile_utils/cpu_utils.cc:102] CPU Frequency: 1599960000 Hz
# 2023-06-11 20:08:12.123578: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x7ff224000b70 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2023-06-11 20:08:12.123629: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version

# %%
# Melakukan training model dengan data training yang telah dibagi sebelumnya dengan jumlah epoch 100 dan batch size 32

history = model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=200, batch_size=64)
# Out:
# Epoch 1/200
# 36/36 [==============================] - 1s 17ms/step - loss: 133.6436 - accuracy: 0.3698 - val_loss: 14.6788 - val_accuracy: 0.4783
# Epoch 2/200
# 36/36 [==============================] - 0s 5ms/step - loss: 17.9979 - accuracy: 0.4961 - val_loss: 31.3387 - val_accuracy: 0.5270
# Epoch 3/200
# 36/36 [==============================] - 0s 5ms/step - loss: 39.0842 - accuracy: 0.4904 - val_loss: 52.6052 - val_accuracy: 0.4783
# Epoch 4/200
# 36/36 [==============================] - 0s 5ms/step - loss: 39.6782 - accuracy: 0.4830 - val_loss: 25.2875 - val_accuracy: 0.4783
# Epoch 5/200
# 36/36 [==============================] - 0s 5ms/step - loss: 17.8594 - accuracy: 0.4852 - val_loss: 19.8080 - val_accuracy: 0.4783
# Epoch 6/200
# 36/36 [==============================] - 0s 6ms/step - loss: 16.1599 - accuracy: 0.4882 - val_loss: 10.3520 - val_accuracy: 0.4348
# Epoch 7/200
# 36/36 [==============================] - 0s 5ms/step - loss: 6.6066 - accuracy: 0.4852 - val_loss: 11.3896 - val_accuracy: 0.4452
# Epoch 8/200
# 36/36 [==============================] - 0s 5ms/step - loss: 10.1722 - accuracy: 0.4935 - val_loss: 7.6832 - val_accuracy: 0.4783
# Epoch 9/200
# 36/36 [==============================] - 0s 5ms/step - loss: 14.6121 - accuracy: 0.4909 - val_loss: 16.6747 - val_accuracy: 0.4348
# Epoch 10/200
# 36/36 [==============================] - 0s 5ms/step - loss: 0.9409 - accuracy: 0.5819 - val_loss: 0.9486 - val_accuracy: 0.5478
# Epoch 189/200
# 36/36 [==============================] - 0s 5ms/step - loss: 0.9412 - accuracy: 0.5767 - val_loss: 0.9313 - val_accuracy: 0.5913
# Epoch 190/200
# 36/36 [==============================] - 0s 5ms/step - loss: 0.9392 - accuracy: 0.5849 - val_loss: 0.9338 - val_accuracy: 0.5896
# Epoch 191/200
# 36/36 [==============================] - 0s 6ms/step - loss: 0.9403 - accuracy: 0.5841 - val_loss: 0.9498 - val_accuracy: 0.5809
# Epoch 192/200
# 36/36 [==============================] - 0s 6ms/step - loss: 0.9376 - accuracy: 0.5836 - val_loss: 0.9379 - val_accuracy: 0.5913
# Epoch 193/200
# 36/36 [==============================] - 0s 5ms/step - loss: 0.9377 - accuracy: 0.5788 - val_loss: 0.9326 - val_accuracy: 0.5809
# Epoch 194/200
# 36/36 [==============================] - 0s 7ms/step - loss: 0.9359 - accuracy: 0.5784 - val_loss: 0.9382 - val_accuracy: 0.5896
# Epoch 195/200
# 36/36 [==============================] - 0s 5ms/step - loss: 0.9393 - accuracy: 0.5810 - val_loss: 0.9319 - val_accuracy: 0.5913
# Epoch 196/200
# 36/36 [==============================] - 0s 5ms/step - loss: 0.9391 - accuracy: 0.5836 - val_loss: 0.9447 - val_accuracy: 0.5548
# Epoch 197/200
# 36/36 [==============================] - 0s 5ms/step - loss: 0.9403 - accuracy: 0.5753 - val_loss: 0.9323 - val_accuracy: 0.5809
# Epoch 198/200
# 36/36 [==============================] - 0s 5ms/step - loss: 0.9398 - accuracy: 0.5723 - val_loss: 0.9312 - val_accuracy: 0.5913
# Epoch 199/200
# 36/36 [==============================] - 0s 5ms/step - loss: 0.9362 - accuracy: 0.5819 - val_loss: 0.9495 - val_accuracy: 0.5809
# Epoch 200/200
# 36/36 [==============================] - 0s 6ms/step - loss: 0.9374 - accuracy: 0.5810 - val_loss: 0.9438 - val_accuracy: 0.5478

# %% [markdown]
# # Convert Model to TFLite

# %%
# COnvert Model to TFLite with quantization

converter = tf.lite.TFLiteConverter.from_keras_model(model)

converter.optimizations = [tf.lite.Optimize.DEFAULT]

tflite_model = converter.convert()


open("filtering_model.tflite", "wb").write(tflite_model)
# Out:
# 2023-06-11 20:08:55.443484: I tensorflow/core/grappler/devices.cc:55] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0
# 2023-06-11 20:08:55.443776: I tensorflow/core/grappler/clusters/single_machine.cc:356] Starting new session
# 2023-06-11 20:08:55.447658: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:797] Optimization results for grappler item: graph_to_optimize
# 2023-06-11 20:08:55.447714: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:799]   function_optimizer: function_optimizer did nothing. time = 0.005ms.
# 2023-06-11 20:08:55.447727: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:799]   function_optimizer: function_optimizer did nothing. time = 0.001ms.
# 2023-06-11 20:08:55.780158: I tensorflow/core/grappler/devices.cc:55] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0
# 2023-06-11 20:08:55.780386: I tensorflow/core/grappler/clusters/single_machine.cc:356] Starting new session
# 2023-06-11 20:08:55.788654: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:797] Optimization results for grappler item: graph_to_optimize
# 2023-06-11 20:08:55.788697: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:799]   constant_folding: Graph size after: 22 nodes (-8), 21 edges (-8), time = 3.386ms.
# 2023-06-11 20:08:55.788729: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:799]   constant_folding: Graph size after: 22 nodes (0), 21 edges (0), time = 1.185ms.
# 15104
