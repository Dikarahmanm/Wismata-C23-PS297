# %% [markdown]
# # Sistem Rekomendasi Destinasi Wisata Kota Bandung Berbasis Collaborative Filtering
# <hr>
#
# #### Sumber data: https://www.kaggle.com/aprabowo/indonesia-tourism-destination
# #### Oleh: [Rafka Imanda Putra](https://www.kaggle.com/rafkaip)

# %% [markdown]
# # Pendahuluan

# %% [markdown]
# <div>
# <img src="https://static.limakaki.com/2017/07/slide_12.jpg" width="900";/>
# </div>

# %% [markdown]
# Sebelum bepergian, biasanya seseorang akan membuat rencana terlebih dahulu tentang lokasi yang akan dikunjungi dan waktu keberangkatannya. Hal ini dilakukan untuk perencanaan sebelum berwisata ke suatu Kota.
#
# Kota Bandung memiliki daya tarik wisata yang cukup tinggi, namun dikutip dari humas.bandung.go.id/ jumlah wisatawan ke Kota Bandung turun 50% pada tahun 2021. Tentunya angka ini wajar karena penyebaran Covid-19 yang mengkhawatirkan di Indonesia.
#
# Untuk periode Oktober 2021, sejumlah wisata di Kota Bandung sudah mulai beroperasi, ini akan menjadi momentum yang tepat untuk menggerakkan pariwisata kembali.
#
# Pada projek ini, saya akan membuat sebuah sistem rekomendasi berbasis collaborative filtering untuk menampilkan top-n recommendation destinasi wisata di Kota Bandung berdasarkan data user, rating, dan place

# %% [markdown]
# # Alur Proses

# %% [markdown]
# ## 1. Mengimpor Library Python yang Dibutuhkan

# %%
# Untuk pengolahan data
import pandas as pd
import numpy as np
from zipfile import ZipFile
from pathlib import Path

# Untuk visualisasi data
import seaborn as sns
import matplotlib.pyplot as plt

# %matplotlib inline
sns.set_palette('Set1')
sns.set()

# Untuk pemodelan
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

# Untuk menghilangkan warnings saat plotting seaborn
import warnings
warnings.filterwarnings('ignore')

# Untuk mengupload file
import os

# %% [markdown]
# ## 2. Menyiapkan Dataset yang digunakan

# %%
# Upload semua dataset yang dipakai
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# %% [markdown]
# ##### Keterangan:
# * tourism_with_id.csv - mengandung informasi tempak wisata di 5 kota besar di Indonesia (hanya kota Bandung yang dipakai)
# * user.csv - mengandung informasi pengguna untuk membuat rekomendasi fitur berdasar pengguna
# * tourism_rating.csv - mengandung informasi pengguna, tempat wisata, dan rating untuk membuat sistem rekomendasi berdasar rating

# %% [markdown]
# ## 3. Data Understanding

# %% [markdown]
# ### 3.1 Menyiapkan Data

# %%
# Menyimpan masing-masing dataset kedalam variabel

rating = pd.read_csv('data/tourism_rating.csv')
place = pd.read_csv('data/tourism_with_id.csv')
user = pd.read_csv('data/user.csv')

# %% [markdown]
# ### 3.2 Eksplorasi Fitur-fitur pada Data

# %% [markdown]
# #### 3.2.1. Data place

# %%
# Melihat gambaran data place

place.head(2)
# Out:
#    Place_Id        Place_Name  \
# 0         1  Monumen Nasional
# 1         2          Kota Tua
#
#                                          Description Category     City  Price  \
# 0  Monumen Nasional atau yang populer disingkat d...   Budaya  Jakarta  20000
# 1  Kota tua di Jakarta, yang juga bernama Kota Tu...   Budaya  Jakarta      0
#
#    Rating  Time_Minutes                                       Coordinate  \
# 0     4.6          15.0          {'lat': -6.1753924, 'lng': 106.8271528}
# 1     4.6          90.0  {'lat': -6.137644799999999, 'lng': 106.8171245}
#
#         Lat        Long  Unnamed: 11  Unnamed: 12
# 0 -6.175392  106.827153          NaN            1
# 1 -6.137645  106.817125          NaN            2

# %%
# Membuang kolom yang tidak dipakai

place = place.drop(['Unnamed: 11','Unnamed: 12'],axis=1)
place.head(2)
# Out:
#    Place_Id        Place_Name  \
# 0         1  Monumen Nasional
# 1         2          Kota Tua
#
#                                          Description Category     City  Price  \
# 0  Monumen Nasional atau yang populer disingkat d...   Budaya  Jakarta  20000
# 1  Kota tua di Jakarta, yang juga bernama Kota Tu...   Budaya  Jakarta      0
#
#    Rating  Time_Minutes                                       Coordinate  \
# 0     4.6          15.0          {'lat': -6.1753924, 'lng': 106.8271528}
# 1     4.6          90.0  {'lat': -6.137644799999999, 'lng': 106.8171245}
#
#         Lat        Long
# 0 -6.175392  106.827153
# 1 -6.137645  106.817125

# %%
# Merubah data agar hanya dari Kota Bandung

place = place[place['City']=='Yogyakarta']
place.head(2)
# Out:
#     Place_Id               Place_Name  \
# 84        85  Taman Pintar Yogyakarta
# 85        86       Keraton Yogyakarta
#
#                                           Description       Category  \
# 84  Taman Pintar Yogyakarta (bahasa Jawa: Hanacara...  Taman Hiburan
# 85  Keraton Ngayogyakarta Hadiningrat atau Keraton...         Budaya
#
#           City  Price  Rating  Time_Minutes  \
# 84  Yogyakarta   6000     4.5         120.0
# 85  Yogyakarta  15000     4.6           NaN
#
#                                          Coordinate       Lat        Long
# 84  {'lat': -7.800671500000001, 'lng': 110.3676551} -7.800671  110.367655
# 85          {'lat': -7.8052845, 'lng': 110.3642031} -7.805284  110.364203

# %%
place.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 126 entries, 84 to 209
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Place_Id      126 non-null    int64
#  1   Place_Name    126 non-null    object
#  2   Description   126 non-null    object
#  3   Category      126 non-null    object
#  4   City          126 non-null    object
#  5   Price         126 non-null    int64
#  6   Rating        126 non-null    float64
#  7   Time_Minutes  60 non-null     float64
#  8   Coordinate    126 non-null    object
#  9   Lat           126 non-null    float64
#  10  Long          126 non-null    float64
# dtypes: float64(4), int64(2), object(5)
# memory usage: 11.8+ KB

# %%
# Membuang kolom yang tidak dipakai

place = place.drop('Time_Minutes', axis=1)

# %% [markdown]
# #### 3.2.2. Data rating

# %%
# melihat gambaran data rating

rating.head()
# Out:
#    User_Id  Place_Id  Place_Ratings
# 0        1       179              3
# 1        1       344              2
# 2        1         5              5
# 3        1       373              3
# 4        1       101              4

# %%
rating.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 3 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   User_Id        10000 non-null  int64
#  1   Place_Id       10000 non-null  int64
#  2   Place_Ratings  10000 non-null  int64
# dtypes: int64(3)
# memory usage: 234.5 KB

# %%
# Merubah data rating agar hanya berisi rating pada tempat wisata dari Kota Bandung

rating = pd.merge(rating, place[['Place_Id']], how='right', on='Place_Id')
rating.head()
# Out:
#    User_Id  Place_Id  Place_Ratings
# 0        2        85              4
# 1       23        85              4
# 2       25        85              2
# 3       39        85              5
# 4       43        85              4

# %%
# Melihat ukuran dataset rating untuk Kota Bandung

rating.shape
# Out:
# (2871, 3)

# %% [markdown]
# #### 3.2.3. Data user

# %%
# Melihat gambaran data user

user.head()
# Out:
#    User_Id                   Location  Age
# 0        1      Semarang, Jawa Tengah   20
# 1        2         Bekasi, Jawa Barat   21
# 2        3        Cirebon, Jawa Barat   23
# 3        4         Bekasi, Jawa Barat   21
# 4        5  Lampung, Sumatera Selatan   20

# %%
# Merubah data user agar hanya berisi user yang pernah megunjungi wisata di Kota Bandung

user = pd.merge(user, rating[['User_Id']], how='right', on='User_Id').drop_duplicates().sort_values('User_Id')
user.head()
# Out:
#       User_Id                   Location  Age
# 868         1      Semarang, Jawa Tengah   20
# 0           2         Bekasi, Jawa Barat   21
# 247         3        Cirebon, Jawa Barat   23
# 621         4         Bekasi, Jawa Barat   21
# 2649        5  Lampung, Sumatera Selatan   20

# %%
# Melihat dataset user yang pernah memberi rating pada wisata di Kota Bandung

user.shape
# Out:
# (300, 3)

# %% [markdown]
# ## 4. Eksplorasi Data

# %%
# Membuat dataframe berisi lokasi dengan jumlah rating terbanyak
top_10 = rating['Place_Id'].value_counts().reset_index()[0:10]
top_10 = pd.merge(top_10, place[['Place_Id','Place_Name']], how='left', left_on='index', right_on='Place_Id')

# Membuat visualisasi wisata dengan jumlah rating terbanyak
plt.figure(figsize=(8,5))
sns.barplot('Place_Id_x', 'Place_Name', data=top_10)
plt.title('Jumlah Tempat Wisata dengan Rating Terbanyak', pad=20)
plt.ylabel('Jumlah Rating')
plt.xlabel('Nama Lokasi')
plt.show()

# %%
# Membuat visualisasi jumlah kategori wisata di Kota Bandung

sns.countplot(y='Category', data=place)
plt.title('Perbandingan Jumlah Kategori Wisata di Kota Bandung', pad=20)
plt.show()

# %%
# Membuat visualisasi distribusi usia user

plt.figure(figsize=(5,3))
sns.boxplot(user['Age']);
plt.title('Distribusi Usia User', pad=20)
plt.show()

# %%
# Membuat visualisasi distribusi harga masuk tempat wisata

plt.figure(figsize=(7,3))
sns.boxplot(place['Price'])
plt.title('Distribusi Harga Masuk Wisata di Kota Bandung', pad=20)
plt.show()

# %%
# Memfilter asal kota dari user
askot = user['Location'].apply(lambda x : x.split(',')[0])

# Visualisasi asal kota dari user
plt.figure(figsize=(8,6))
sns.countplot(y=askot)
plt.title('Jumlah Asal Kota dari User')
plt.show()

# %% [markdown]
# ## 5. Persiapan Data untuk Pemodelan

# %% [markdown]
# ### 5.1. Membuat Salinan Data rating

# %%
# Membaca dataset untuk dilakukan encoding
 
df = rating.copy()
df.head()
# Out:
#    User_Id  Place_Id  Place_Ratings
# 0        2        85              4
# 1       23        85              4
# 2       25        85              2
# 3       39        85              5
# 4       43        85              4

# %% [markdown]
# ### 5.2. Melakukan Encoding

# %% [markdown]
# #### 5.2.1. Membuat Fungsi untuk Melakukan Encoding

# %%
def dict_encoder(col, data=df):

  # Mengubah kolom suatu dataframe menjadi list tanpa nilai yang sama
  unique_val = data[col].unique().tolist()

  # Melakukan encoding value kolom suatu dataframe ke angka
  val_to_val_encoded = {x: i for i, x in enumerate(unique_val)}

  # Melakukan proses encoding angka ke value dari kolom suatu dataframe
  val_encoded_to_val = {i: x for i, x in enumerate(unique_val)}
  return val_to_val_encoded, val_encoded_to_val

# %% [markdown]
# #### 5.2.2. Encoding dan Mapping Kolom User

# %%
# Encoding User_Id
user_to_user_encoded, user_encoded_to_user = dict_encoder('User_Id')

# Mapping User_Id ke dataframe
df['user'] = df['User_Id'].map(user_to_user_encoded)

# %% [markdown]
# #### 5.2.3. Encoding dan Mapping Kolom Place

# %%
# Encoding Place_Id
place_to_place_encoded, place_encoded_to_place = dict_encoder('Place_Id')

# Mapping Place_Id ke dataframe place
df['place'] = df['Place_Id'].map(place_to_place_encoded)

# %% [markdown]
# ### 5.3. Melihat Gambaran Data untuk Pemodelan

# %%
# Mendapatkan jumlah user dan place
num_users, num_place = len(user_to_user_encoded), len(place_to_place_encoded)
 
# Mengubah rating menjadi nilai float
df['Place_Ratings'] = df['Place_Ratings'].values.astype(np.float32)
 
# Mendapatkan nilai minimum dan maksimum rating
min_rating, max_rating = min(df['Place_Ratings']), max(df['Place_Ratings'])
 
print(f'Number of User: {num_users}, Number of Place: {num_place}, Min Rating: {min_rating}, Max Rating: {max_rating}')
# Out:
# Number of User: 300, Number of Place: 126, Min Rating: 1.0, Max Rating: 5.0

# %%
# Mengacak dataset
df = df.sample(frac=1, random_state=42)
df.head(2)
# Out:
#       User_Id  Place_Id  Place_Ratings  user  place
# 729       194       115            4.0   130     30
# 2067      276       176            2.0    23     91

# %% [markdown]
# ## 6. Pemodelan Machine Learning dengan RecommenderNet

# %% [markdown]
# ### 6.1. Membagi data train dan test

# %%
# Membuat variabel x untuk mencocokkan data user dan place menjadi satu value
x = df[['user', 'place']].values
 
# Membuat variabel y untuk membuat rating dari hasil 
y = df['Place_Ratings'].apply(lambda x: (x - min_rating) / (max_rating - min_rating)).values
 
# Membagi menjadi 80% data train dan 20% data validasi
train_indices = int(0.8 * df.shape[0])
x_train, x_val, y_train, y_val = (
    x[:train_indices],
    x[train_indices:],
    y[:train_indices],
    y[train_indices:]
)

# %% [markdown]
# ### 6.2. Menyiapkan Model

# %% [markdown]
# #### 6.2.1. Inisialisasi Fungsi

# %%
class RecommenderNet(tf.keras.Model):
 
  # Insialisasi fungsi
  def __init__(self, num_users, num_places, embedding_size, **kwargs):
    super(RecommenderNet, self).__init__(**kwargs)
    self.num_users = num_users
    self.num_places = num_places
    self.embedding_size = embedding_size
    self.user_embedding = layers.Embedding( # layer embedding user
        num_users,
        embedding_size,
        embeddings_initializer = 'he_normal',
        embeddings_regularizer = keras.regularizers.l2(1e-6)
    )
    self.user_bias = layers.Embedding(num_users, 1) # layer embedding user bias
    self.places_embedding = layers.Embedding( # layer embeddings places
        num_places,
        embedding_size,
        embeddings_initializer = 'he_normal',
        embeddings_regularizer = keras.regularizers.l2(1e-6)
    )
    self.places_bias = layers.Embedding(num_places, 1) # layer embedding places bias
 
  def call(self, inputs):
    user_vector = self.user_embedding(inputs[:,0]) # memanggil layer embedding 1
    user_bias = self.user_bias(inputs[:, 0]) # memanggil layer embedding 2
    places_vector = self.places_embedding(inputs[:, 1]) # memanggil layer embedding 3
    places_bias = self.places_bias(inputs[:, 1]) # memanggil layer embedding 4
 
    dot_user_places = tf.tensordot(user_vector, places_vector, 2) 
 
    x = dot_user_places + user_bias + places_bias
    
    return tf.nn.sigmoid(x) # activation sigmoid

# %% [markdown]
# #### 6.2.2. Inisialisasi Model

# %%
model = RecommenderNet(num_users, num_place, 50) # inisialisasi model
 
# model compile
model.compile(
    loss = tf.keras.losses.BinaryCrossentropy(),
    optimizer = keras.optimizers.Adam(learning_rate=0.0004),
    metrics=[tf.keras.metrics.RootMeanSquaredError()]
)

# %% [markdown]
# #### 6.2.2. Inisialisasi Callbacks

# %%
 class myCallback(tf.keras.callbacks.Callback):
  def on_epoch_end(self, epoch, logs={}):
    if(logs.get('val_root_mean_squared_error')<0.25):
      print('Lapor! Metriks validasi sudah sesuai harapan')
      self.model.stop_training = True

# %% [markdown]
# #### 6.2.3. Proses Training

# %%
# Memulai training
 
history = model.fit(
    x = x_train,
    y = y_train,
    epochs = 100,
    validation_data = (x_val, y_val),
    callbacks = [myCallback()]
)
# Out:
# Epoch 1/100
# 72/72 [==============================] - 3s 11ms/step - loss: 0.7161 - root_mean_squared_error: 0.3663 - val_loss: 0.7196 - val_root_mean_squared_error: 0.3586
# Epoch 2/100
# 72/72 [==============================] - 0s 4ms/step - loss: 0.7123 - root_mean_squared_error: 0.3640 - val_loss: 0.7203 - val_root_mean_squared_error: 0.3590
# Epoch 3/100
# 72/72 [==============================] - 0s 5ms/step - loss: 0.7078 - root_mean_squared_error: 0.3609 - val_loss: 0.7209 - val_root_mean_squared_error: 0.3595
# Epoch 4/100
# 72/72 [==============================] - 0s 5ms/step - loss: 0.7067 - root_mean_squared_error: 0.3603 - val_loss: 0.7223 - val_root_mean_squared_error: 0.3603
# Epoch 5/100
# 72/72 [==============================] - 0s 5ms/step - loss: 0.7028 - root_mean_squared_error: 0.3578 - val_loss: 0.7223 - val_root_mean_squared_error: 0.3603
# Epoch 6/100
# 72/72 [==============================] - 0s 5ms/step - loss: 0.7052 - root_mean_squared_error: 0.3594 - val_loss: 0.7224 - val_root_mean_squared_error: 0.3604
# Epoch 7/100
# 72/72 [==============================] - 0s 4ms/step - loss: 0.7002 - root_mean_squared_error: 0.3559 - val_loss: 0.7214 - val_root_mean_squared_error: 0.3598
# Epoch 8/100
# 72/72 [==============================] - 0s 4ms/step - loss: 0.7023 - root_mean_squared_error: 0.3575 - val_loss: 0.7209 - val_root_mean_squared_error: 0.3595
# Epoch 9/100
# 72/72 [==============================] - 0s 4ms/step - loss: 0.7031 - root_mean_squared_error: 0.3578 - val_loss: 0.7200 - val_root_mean_squared_error: 0.3590
# Epoch 10/100
# 72/72 [==============================] - 0s 5ms/step - loss: 0.6982 - root_mean_squared_error: 0.3546 - val_loss: 0.7197 - val_root_mean_squared_error: 0.3588
# Epoch 11/100
# 72/72 [==============================] - 0s 4ms/step - loss: 0.7003 - root_mean_squared_error: 0.3558 - val_loss: 0.7200 - val_root_mean_squared_error: 0.3591
# Epoch 12/100
# 72/72 [==============================] - 0s 5ms/step - loss: 0.7033 - root_mean_squared_error: 0.3577 - val_loss: 0.7210 - val_root_mean_squared_error: 0.3597
# Epoch 13/100
# 72/72 [==============================] - 0s 4ms/step - loss: 0.6913 - root_mean_squared_error: 0.3498 - val_loss: 0.7212 - val_root_mean_squared_error: 0.3598
# Epoch 14/100
# 72/72 [==============================] - 0s 4ms/step - loss: 0.7019 - root_mean_squared_error: 0.3571 - val_loss: 0.7207 - val_root_mean_squared_error: 0.3596
# Epoch 15/100
# 72/72 [==============================] - 0s 4ms/step - loss: 0.6918 - root_mean_squared_error: 0.3503 - val_loss: 0.7214 - val_root_mean_squared_error: 0.3600
# Epoch 16/100
# 72/72 [==============================] - 0s 5ms/step - loss: 0.6879 - root_mean_squared_error: 0.3476 - val_loss: 0.7216 - val_root_mean_squared_error: 0.3601
# Epoch 17/100
# 72/72 [==============================] - 0s 5ms/step - loss: 0.6889 - root_mean_squared_error: 0.3482 - val_loss: 0.7215 - val_root_mean_squared_error: 0.3601
# Epoch 18/100
# 72/72 [==============================] - 0s 5ms/step - loss: 0.6950 - root_mean_squared_error: 0.3524 - val_loss: 0.7213 - val_root_mean_squared_error: 0.3599
# Epoch 19/100
# 72/72 [==============================] - 0s 5ms/step - loss: 0.6892 - root_mean_squared_error: 0.3484 - val_loss: 0.7202 - val_root_mean_squared_error: 0.3593
# Epoch 20/100
# 72/72 [==============================] - 0s 5ms/step - loss: 0.6909 - root_mean_squared_error: 0.3497 - val_loss: 0.7189 - val_root_mean_squared_error: 0.3584
# Epoch 21/100
# 72/72 [==============================] - 0s 5ms/step - loss: 0.6856 - root_mean_squared_error: 0.3458 - val_loss: 0.7166 - val_root_mean_squared_error: 0.3569
# Epoch 22/100
# 72/72 [==============================] - 0s 5ms/step - loss: 0.6843 - root_mean_squared_error: 0.3450 - val_loss: 0.7167 - val_root_mean_squared_error: 0.3570
# Epoch 23/100
# 72/72 [==============================] - 0s 4ms/step - loss: 0.6894 - root_mean_squared_error: 0.3486 - val_loss: 0.7162 - val_root_mean_squared_error: 0.3566
# Epoch 24/100
# 72/72 [==============================] - 0s 4ms/step - loss: 0.6811 - root_mean_squared_error: 0.3427 - val_loss: 0.7154 - val_root_mean_squared_error: 0.3561
# Epoch 25/100
# 72/72 [==============================] - 0s 5ms/step - loss: 0.6843 - root_mean_squared_error: 0.3450 - val_loss: 0.7146 - val_root_mean_squared_error: 0.3555
# Epoch 26/100
# 72/72 [==============================] - 0s 4ms/step - loss: 0.6853 - root_mean_squared_error: 0.3457 - val_loss: 0.7143 - val_root_mean_squared_error: 0.3553
# Epoch 27/100
# 72/72 [==============================] - 0s 4ms/step - loss: 0.6837 - root_mean_squared_error: 0.3446 - val_loss: 0.7136 - val_root_mean_squared_error: 0.3548
# Epoch 28/100
# 72/72 [==============================] - 0s 4ms/step - loss: 0.6827 - root_mean_squared_error: 0.3437 - val_loss: 0.7138 - val_root_mean_squared_error: 0.3549
# Epoch 29/100
# 72/72 [==============================] - 0s 4ms/step - loss: 0.6796 - root_mean_squared_error: 0.3417 - val_loss: 0.7130 - val_root_mean_squared_error: 0.3544
# Epoch 30/100
# 72/72 [==============================] - 0s 5ms/step - loss: 0.6842 - root_mean_squared_error: 0.3449 - val_loss: 0.7120 - val_root_mean_squared_error: 0.3537
# Epoch 31/100
# 72/72 [==============================] - 0s 4ms/step - loss: 0.6812 - root_mean_squared_error: 0.3428 - val_loss: 0.7116 - val_root_mean_squared_error: 0.3535
# Epoch 32/100
# 72/72 [==============================] - 0s 5ms/step - loss: 0.6799 - root_mean_squared_error: 0.3418 - val_loss: 0.7113 - val_root_mean_squared_error: 0.3533
# Epoch 33/100
# 72/72 [==============================] - 0s 4ms/step - loss: 0.6794 - root_mean_squared_error: 0.3416 - val_loss: 0.7100 - val_root_mean_squared_error: 0.3525
# Epoch 34/100
# 72/72 [==============================] - 0s 5ms/step - loss: 0.6765 - root_mean_squared_error: 0.3394 - val_loss: 0.7112 - val_root_mean_squared_error: 0.3533
# Epoch 35/100
# 72/72 [==============================] - 0s 5ms/step - loss: 0.6770 - root_mean_squared_error: 0.3398 - val_loss: 0.7102 - val_root_mean_squared_error: 0.3525
# Epoch 36/100
# 72/72 [==============================] - 0s 5ms/step - loss: 0.6728 - root_mean_squared_error: 0.3368 - val_loss: 0.7101 - val_root_mean_squared_error: 0.3525
# Epoch 37/100
# 72/72 [==============================] - 0s 4ms/step - loss: 0.6757 - root_mean_squared_error: 0.3389 - val_loss: 0.7101 - val_root_mean_squared_error: 0.3525
# Epoch 38/100
# 72/72 [==============================] - 0s 5ms/step - loss: 0.6753 - root_mean_squared_error: 0.3386 - val_loss: 0.7100 - val_root_mean_squared_error: 0.3524
# Epoch 39/100
# 72/72 [==============================] - 0s 5ms/step - loss: 0.6752 - root_mean_squared_error: 0.3385 - val_loss: 0.7099 - val_root_mean_squared_error: 0.3523
# Epoch 40/100
# 72/72 [==============================] - 0s 4ms/step - loss: 0.6704 - root_mean_squared_error: 0.3351 - val_loss: 0.7101 - val_root_mean_squared_error: 0.3525
# Epoch 41/100
# 72/72 [==============================] - 0s 4ms/step - loss: 0.6753 - root_mean_squared_error: 0.3386 - val_loss: 0.7102 - val_root_mean_squared_error: 0.3525
# Epoch 42/100
# 72/72 [==============================] - 0s 5ms/step - loss: 0.6758 - root_mean_squared_error: 0.3389 - val_loss: 0.7104 - val_root_mean_squared_error: 0.3526
# Epoch 43/100
# 72/72 [==============================] - 0s 5ms/step - loss: 0.6712 - root_mean_squared_error: 0.3357 - val_loss: 0.7103 - val_root_mean_squared_error: 0.3526
# Epoch 44/100
# 72/72 [==============================] - 0s 4ms/step - loss: 0.6703 - root_mean_squared_error: 0.3350 - val_loss: 0.7093 - val_root_mean_squared_error: 0.3519
# Epoch 45/100
# 72/72 [==============================] - 0s 5ms/step - loss: 0.6721 - root_mean_squared_error: 0.3363 - val_loss: 0.7097 - val_root_mean_squared_error: 0.3522
# Epoch 46/100
# 72/72 [==============================] - 0s 5ms/step - loss: 0.6703 - root_mean_squared_error: 0.3350 - val_loss: 0.7096 - val_root_mean_squared_error: 0.3522
# Epoch 47/100
# 72/72 [==============================] - 0s 5ms/step - loss: 0.6667 - root_mean_squared_error: 0.3322 - val_loss: 0.7099 - val_root_mean_squared_error: 0.3523
# Epoch 48/100
# 72/72 [==============================] - 0s 4ms/step - loss: 0.6703 - root_mean_squared_error: 0.3350 - val_loss: 0.7094 - val_root_mean_squared_error: 0.3519
# Epoch 49/100
# 72/72 [==============================] - 0s 4ms/step - loss: 0.6669 - root_mean_squared_error: 0.3325 - val_loss: 0.7082 - val_root_mean_squared_error: 0.3512
# Epoch 50/100
# 72/72 [==============================] - 0s 5ms/step - loss: 0.6664 - root_mean_squared_error: 0.3321 - val_loss: 0.7086 - val_root_mean_squared_error: 0.3514
# Epoch 51/100
# 72/72 [==============================] - 0s 5ms/step - loss: 0.6679 - root_mean_squared_error: 0.3332 - val_loss: 0.7080 - val_root_mean_squared_error: 0.3511
# Epoch 52/100
# 72/72 [==============================] - 0s 4ms/step - loss: 0.6663 - root_mean_squared_error: 0.3320 - val_loss: 0.7080 - val_root_mean_squared_error: 0.3510
# Epoch 53/100
# 72/72 [==============================] - 0s 5ms/step - loss: 0.6682 - root_mean_squared_error: 0.3334 - val_loss: 0.7071 - val_root_mean_squared_error: 0.3505
# Epoch 54/100
# 72/72 [==============================] - 0s 5ms/step - loss: 0.6640 - root_mean_squared_error: 0.3304 - val_loss: 0.7077 - val_root_mean_squared_error: 0.3509
# Epoch 55/100
# 72/72 [==============================] - 0s 4ms/step - loss: 0.6658 - root_mean_squared_error: 0.3316 - val_loss: 0.7075 - val_root_mean_squared_error: 0.3508
# Epoch 56/100
# 72/72 [==============================] - 0s 5ms/step - loss: 0.6660 - root_mean_squared_error: 0.3318 - val_loss: 0.7075 - val_root_mean_squared_error: 0.3508
# Epoch 57/100
# 72/72 [==============================] - 0s 5ms/step - loss: 0.6658 - root_mean_squared_error: 0.3316 - val_loss: 0.7075 - val_root_mean_squared_error: 0.3508
# Epoch 58/100
# 72/72 [==============================] - 0s 4ms/step - loss: 0.6661 - root_mean_squared_error: 0.3318 - val_loss: 0.7073 - val_root_mean_squared_error: 0.3507
# Epoch 59/100
# 72/72 [==============================] - 0s 4ms/step - loss: 0.6643 - root_mean_squared_error: 0.3305 - val_loss: 0.7069 - val_root_mean_squared_error: 0.3504
# Epoch 60/100
# 72/72 [==============================] - 0s 4ms/step - loss: 0.6640 - root_mean_squared_error: 0.3304 - val_loss: 0.7065 - val_root_mean_squared_error: 0.3501
# Epoch 61/100
# 72/72 [==============================] - 0s 5ms/step - loss: 0.6643 - root_mean_squared_error: 0.3306 - val_loss: 0.7063 - val_root_mean_squared_error: 0.3499
# Epoch 62/100
# 72/72 [==============================] - 0s 5ms/step - loss: 0.6633 - root_mean_squared_error: 0.3299 - val_loss: 0.7061 - val_root_mean_squared_error: 0.3498
# Epoch 63/100
# 72/72 [==============================] - 0s 4ms/step - loss: 0.6634 - root_mean_squared_error: 0.3299 - val_loss: 0.7065 - val_root_mean_squared_error: 0.3501
# Epoch 64/100
# 72/72 [==============================] - 0s 5ms/step - loss: 0.6622 - root_mean_squared_error: 0.3290 - val_loss: 0.7064 - val_root_mean_squared_error: 0.3500
# Epoch 65/100
# 72/72 [==============================] - 0s 4ms/step - loss: 0.6636 - root_mean_squared_error: 0.3300 - val_loss: 0.7071 - val_root_mean_squared_error: 0.3505
# Epoch 66/100
# 72/72 [==============================] - 0s 4ms/step - loss: 0.6630 - root_mean_squared_error: 0.3296 - val_loss: 0.7073 - val_root_mean_squared_error: 0.3506
# Epoch 67/100
# 72/72 [==============================] - 0s 4ms/step - loss: 0.6605 - root_mean_squared_error: 0.3278 - val_loss: 0.7078 - val_root_mean_squared_error: 0.3510
# Epoch 68/100
# 72/72 [==============================] - 0s 4ms/step - loss: 0.6600 - root_mean_squared_error: 0.3274 - val_loss: 0.7077 - val_root_mean_squared_error: 0.3509
# Epoch 69/100
# 72/72 [==============================] - 0s 4ms/step - loss: 0.6603 - root_mean_squared_error: 0.3276 - val_loss: 0.7076 - val_root_mean_squared_error: 0.3508
# Epoch 70/100
# 72/72 [==============================] - 0s 4ms/step - loss: 0.6584 - root_mean_squared_error: 0.3263 - val_loss: 0.7073 - val_root_mean_squared_error: 0.3506
# Epoch 71/100
# 72/72 [==============================] - 0s 4ms/step - loss: 0.6593 - root_mean_squared_error: 0.3269 - val_loss: 0.7076 - val_root_mean_squared_error: 0.3508
# Epoch 72/100
# 72/72 [==============================] - 0s 4ms/step - loss: 0.6605 - root_mean_squared_error: 0.3278 - val_loss: 0.7081 - val_root_mean_squared_error: 0.3511
# Epoch 73/100
# 72/72 [==============================] - 0s 5ms/step - loss: 0.6576 - root_mean_squared_error: 0.3256 - val_loss: 0.7080 - val_root_mean_squared_error: 0.3510
# Epoch 74/100
# 72/72 [==============================] - 0s 5ms/step - loss: 0.6616 - root_mean_squared_error: 0.3286 - val_loss: 0.7081 - val_root_mean_squared_error: 0.3511
# Epoch 75/100
# 72/72 [==============================] - 0s 5ms/step - loss: 0.6605 - root_mean_squared_error: 0.3278 - val_loss: 0.7084 - val_root_mean_squared_error: 0.3513
# Epoch 76/100
# 72/72 [==============================] - 0s 4ms/step - loss: 0.6590 - root_mean_squared_error: 0.3267 - val_loss: 0.7077 - val_root_mean_squared_error: 0.3508
# Epoch 77/100
# 72/72 [==============================] - 0s 4ms/step - loss: 0.6601 - root_mean_squared_error: 0.3275 - val_loss: 0.7075 - val_root_mean_squared_error: 0.3506
# Epoch 78/100
# 72/72 [==============================] - 0s 4ms/step - loss: 0.6600 - root_mean_squared_error: 0.3274 - val_loss: 0.7075 - val_root_mean_squared_error: 0.3507
# Epoch 79/100
# 72/72 [==============================] - 0s 4ms/step - loss: 0.6585 - root_mean_squared_error: 0.3263 - val_loss: 0.7081 - val_root_mean_squared_error: 0.3510
# Epoch 80/100
# 72/72 [==============================] - 0s 4ms/step - loss: 0.6580 - root_mean_squared_error: 0.3259 - val_loss: 0.7087 - val_root_mean_squared_error: 0.3515
# Epoch 81/100
# 72/72 [==============================] - 0s 4ms/step - loss: 0.6576 - root_mean_squared_error: 0.3256 - val_loss: 0.7081 - val_root_mean_squared_error: 0.3511
# Epoch 82/100
# 72/72 [==============================] - 0s 4ms/step - loss: 0.6593 - root_mean_squared_error: 0.3269 - val_loss: 0.7078 - val_root_mean_squared_error: 0.3509
# Epoch 83/100
# 72/72 [==============================] - 0s 4ms/step - loss: 0.6542 - root_mean_squared_error: 0.3231 - val_loss: 0.7081 - val_root_mean_squared_error: 0.3511
# Epoch 84/100
# 72/72 [==============================] - 0s 4ms/step - loss: 0.6569 - root_mean_squared_error: 0.3251 - val_loss: 0.7088 - val_root_mean_squared_error: 0.3515
# Epoch 85/100
# 72/72 [==============================] - 0s 4ms/step - loss: 0.6567 - root_mean_squared_error: 0.3249 - val_loss: 0.7086 - val_root_mean_squared_error: 0.3514
# Epoch 86/100
# 72/72 [==============================] - 0s 4ms/step - loss: 0.6563 - root_mean_squared_error: 0.3247 - val_loss: 0.7084 - val_root_mean_squared_error: 0.3513
# Epoch 87/100
# 72/72 [==============================] - 0s 4ms/step - loss: 0.6573 - root_mean_squared_error: 0.3255 - val_loss: 0.7086 - val_root_mean_squared_error: 0.3514
# Epoch 88/100
# 72/72 [==============================] - 0s 4ms/step - loss: 0.6534 - root_mean_squared_error: 0.3226 - val_loss: 0.7081 - val_root_mean_squared_error: 0.3510
# Epoch 89/100
# 72/72 [==============================] - 0s 4ms/step - loss: 0.6563 - root_mean_squared_error: 0.3247 - val_loss: 0.7082 - val_root_mean_squared_error: 0.3511
# Epoch 90/100
# 72/72 [==============================] - 0s 4ms/step - loss: 0.6545 - root_mean_squared_error: 0.3234 - val_loss: 0.7088 - val_root_mean_squared_error: 0.3514
# Epoch 91/100
# 72/72 [==============================] - 0s 5ms/step - loss: 0.6564 - root_mean_squared_error: 0.3247 - val_loss: 0.7093 - val_root_mean_squared_error: 0.3518
# Epoch 92/100
# 72/72 [==============================] - 0s 5ms/step - loss: 0.6544 - root_mean_squared_error: 0.3233 - val_loss: 0.7094 - val_root_mean_squared_error: 0.3519
# Epoch 93/100
# 72/72 [==============================] - 0s 4ms/step - loss: 0.6564 - root_mean_squared_error: 0.3248 - val_loss: 0.7098 - val_root_mean_squared_error: 0.3521
# Epoch 94/100
# 72/72 [==============================] - 0s 5ms/step - loss: 0.6543 - root_mean_squared_error: 0.3233 - val_loss: 0.7101 - val_root_mean_squared_error: 0.3523
# Epoch 95/100
# 72/72 [==============================] - 0s 4ms/step - loss: 0.6510 - root_mean_squared_error: 0.3208 - val_loss: 0.7107 - val_root_mean_squared_error: 0.3526
# Epoch 96/100
# 72/72 [==============================] - 0s 4ms/step - loss: 0.6554 - root_mean_squared_error: 0.3240 - val_loss: 0.7105 - val_root_mean_squared_error: 0.3525
# Epoch 97/100
# 72/72 [==============================] - 0s 4ms/step - loss: 0.6545 - root_mean_squared_error: 0.3235 - val_loss: 0.7113 - val_root_mean_squared_error: 0.3531
# Epoch 98/100
# 72/72 [==============================] - 0s 5ms/step - loss: 0.6533 - root_mean_squared_error: 0.3225 - val_loss: 0.7106 - val_root_mean_squared_error: 0.3526
# Epoch 99/100
# 72/72 [==============================] - 0s 5ms/step - loss: 0.6548 - root_mean_squared_error: 0.3236 - val_loss: 0.7117 - val_root_mean_squared_error: 0.3533
# Epoch 100/100
# 72/72 [==============================] - 0s 5ms/step - loss: 0.6532 - root_mean_squared_error: 0.3224 - val_loss: 0.7119 - val_root_mean_squared_error: 0.3534

# %%
# Menampilkan plot loss dan validation

plt.plot(history.history['root_mean_squared_error'])
plt.plot(history.history['val_root_mean_squared_error'])
plt.title('model_metrics')
plt.ylabel('root_mean_squared_error')
plt.xlabel('epoch')
plt.ylim(ymin=0, ymax=0.4)
plt.legend(['train', 'test'], loc='center left')
plt.show()

# %% [markdown]
# ## 7. Memprediksi Top 7 Rekomendasi

# %% [markdown]
# #### 7.1 Menyiapkan DataFrame untuk Menampilkan Hasil Rekomendasi

# %%
# Menyiapkan dataframe
place_df = place[['Place_Id','Place_Name','Category','Rating','Price']]
place_df.columns = ['id','place_name','category','rating','price']
df = rating.copy()

# %% [markdown]
# #### 7.2. Menyiapkan contoh User untuk Menampilkan Rekomendasi

# %% [markdown]
# #### 7.2.1 Mencari User

# %%
# Mengambil sample user
user_id = df.User_Id.sample(1).iloc[0]
place_visited_by_user = df[df.User_Id == user_id]

# %% [markdown]
# #### 7.2.2. Mencari Lokasi yang belum Dikunjungi User

# %%
# Membuat data lokasi yang belum dikunjungi user
place_not_visited = place_df[~place_df['id'].isin(place_visited_by_user.Place_Id.values)]['id'] 
place_not_visited = list(
    set(place_not_visited)
    .intersection(set(place_to_place_encoded.keys()))
)
 
place_not_visited = [[place_to_place_encoded.get(x)] for x in place_not_visited]
user_encoder = user_to_user_encoded.get(user_id)
user_place_array = np.hstack(
    ([[user_encoder]] * len(place_not_visited), place_not_visited)
)

# %% [markdown]
# ### 7.3. Menampilkan Hasil Rekomendasi untuk User

# %%
# Mengambil top 7 recommendation
ratings = model.predict(user_place_array).flatten()
top_ratings_indices = ratings.argsort()[-7:][::-1]
recommended_place_ids = [
    place_encoded_to_place.get(place_not_visited[x][0]) for x in top_ratings_indices
]
 
print('Daftar rekomendasi untuk: {}'.format('User ' + str(user_id)))
print('===' * 15,'\n')
print('----' * 15)
print('Tempat dengan rating wisata paling tinggi dari user')
print('----' * 15)
 
top_place_user = (
    place_visited_by_user.sort_values(
        by = 'Place_Ratings',
        ascending=False
    )
    .head(5)
    .Place_Id.values
)
 
place_df_rows = place_df[place_df['id'].isin(top_place_user)]
for row in place_df_rows.itertuples():
    print(row.place_name, ':', row.category)

print('')
print('----' * 15)
print('Top 7 place recommendation')
print('----' * 15)
 
recommended_place = place_df[place_df['id'].isin(recommended_place_ids)]
for row, i in zip(recommended_place.itertuples(), range(1,8)):
    print(i,'.', row.place_name, '\n    ', row.category, ',', 'Harga Tiket Masuk ', row.price, ',', 'Rating Wisata ', row.rating,'\n')

print('==='*15)
# Out:
# Daftar rekomendasi untuk: User 247
# =============================================
#
# ------------------------------------------------------------
# Tempat dengan rating wisata paling tinggi dari user
# ------------------------------------------------------------
# Sindu Kusuma Edupark (SKE) : Taman Hiburan
# Nol Kilometer Jl.Malioboro : Taman Hiburan
# Desa Wisata Sungai Code Jogja Kota : Taman Hiburan
# Jurang Tembelan Kanigoro : Taman Hiburan
# Pantai Patihan : Bahari
#
# ------------------------------------------------------------
# Top 7 place recommendation
# ------------------------------------------------------------
# 1 . Sumur Gumuling
#      Taman Hiburan , Harga Tiket Masuk  7000 , Rating Wisata  4.5
#
# 2 . Monumen Yogya Kembali
#      Budaya , Harga Tiket Masuk  15000 , Rating Wisata  4.5
#
# 3 . Bukit Bintang Yogyakarta
#      Taman Hiburan , Harga Tiket Masuk  25000 , Rating Wisata  4.5
#
# 4 . The World Landmarks - Merapi Park Yogyakarta
#      Taman Hiburan , Harga Tiket Masuk  22000 , Rating Wisata  4.2
#
# 5 . Desa Wisata Gamplong
#      Taman Hiburan , Harga Tiket Masuk  10000 , Rating Wisata  4.4
#
# 6 . Puncak Gunung Api Purba - Nglanggeran
#      Cagar Alam , Harga Tiket Masuk  10000 , Rating Wisata  4.7
#
# 7 . Pantai Baron
#      Bahari , Harga Tiket Masuk  10000 , Rating Wisata  4.4
#
# =============================================

# %%
#

# %% [markdown]
# # Penutup

# %% [markdown]
# Model untuk menampilkan top 7 rekomendasi tempat wisata telah selesai dibuat dan model ini dapat digunakan untuk menampilkan rekomendasi kepada user yang harapannya dapat meningkatkan jumlah wisatawan di Kota Bandung. Namun demikian beberapa pengembangan lain masih dapat dilakukan agar dapat membuat model yang menampilkan rekomendasi yang lebih sesuai dengan kebiasaan pengguna, dll.

# %% [markdown]
# ## *Referensi*

# %% [markdown]
# * Seaborn : https://seaborn.pydata.org/tutorial.html
# * Callback : https://www.tensorflow.org/api_docs/python/tf/keras/callbacks/Callback
# * Lainnya:
#   * https://github.com/AgungP88/getloc-apps/tree/machine-learning
#   * https://www.kaggle.com/ibtesama/getting-started-with-a-movie-recommendation-system
#   * https://www.kaggle.com/aprabowo/indonesia-tourism-destination
#   * https://www.dicoding.com/academies/319
