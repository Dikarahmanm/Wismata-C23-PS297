# %%
import pandas as pd
import numpy as np
from zipfile import ZipFile
from pathlib import Path
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler, MinMaxScaler

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

# %%
rating = pd.read_csv('./data/tourism_rating.csv')
destination = pd.read_csv('./data/tourism_with_id.csv')
user = pd.read_csv('./data/user.csv')

# %% [markdown]
# <h2> PRE-PROCESSING

# %% [markdown]
# <h4> DATA DESTINATION

# %%
destination.head()
# Out:
#    IdWisata                         Place_Name  \
# 0         1                   Monumen Nasional
# 1         2                           Kota Tua
# 2         3                      Dunia Fantasi
# 3         4  Taman Mini Indonesia Indah (TMII)
# 4         5           Atlantis Water Adventure
#
#                                          Description       Category     City  \
# 0  Monumen Nasional atau yang populer disingkat d...         Budaya  Jakarta
# 1  Kota tua di Jakarta, yang juga bernama Kota Tu...         Budaya  Jakarta
# 2  Dunia Fantasi atau disebut juga Dufan adalah t...  Taman Hiburan  Jakarta
# 3  Taman Mini Indonesia Indah merupakan suatu kaw...  Taman Hiburan  Jakarta
# 4  Atlantis Water Adventure atau dikenal dengan A...  Taman Hiburan  Jakarta
#
#     Price  Rating  Time_Minutes  \
# 0   20000     4.6          15.0
# 1       0     4.6          90.0
# 2  270000     4.6         360.0
# 3   10000     4.5           NaN
# 4   94000     4.5          60.0
#
#                                         Coordinate       Lat        Long  \
# 0          {'lat': -6.1753924, 'lng': 106.8271528} -6.175392  106.827153
# 1  {'lat': -6.137644799999999, 'lng': 106.8171245} -6.137645  106.817125
# 2  {'lat': -6.125312399999999, 'lng': 106.8335377} -6.125312  106.833538
# 3  {'lat': -6.302445899999999, 'lng': 106.8951559} -6.302446  106.895156
# 4             {'lat': -6.12419, 'lng': 106.839134} -6.124190  106.839134
#
#    Unnamed: 11  Unnamed: 12
# 0          NaN            1
# 1          NaN            2
# 2          NaN            3
# 3          NaN            4
# 4          NaN            5

# %%
destination = destination.drop(['Unnamed: 11','Unnamed: 12', 'Time_Minutes'], axis=1)
destination.head(2)
# Out:
#    IdWisata        Place_Name  \
# 0         1  Monumen Nasional
# 1         2          Kota Tua
#
#                                          Description Category     City  Price  \
# 0  Monumen Nasional atau yang populer disingkat d...   Budaya  Jakarta  20000
# 1  Kota tua di Jakarta, yang juga bernama Kota Tu...   Budaya  Jakarta      0
#
#    Rating                                       Coordinate       Lat  \
# 0     4.6          {'lat': -6.1753924, 'lng': 106.8271528} -6.175392
# 1     4.6  {'lat': -6.137644799999999, 'lng': 106.8171245} -6.137645
#
#          Long
# 0  106.827153
# 1  106.817125

# %%
destination_jogja = destination[destination['City'] == 'Yogyakarta']
destination_jogja.head()
# Out:
#     IdWisata                           Place_Name  \
# 84        85              Taman Pintar Yogyakarta
# 85        86                   Keraton Yogyakarta
# 86        87           Sindu Kusuma Edupark (SKE)
# 87        88  Museum Benteng Vredeburg Yogyakarta
# 88        89                 De Mata Museum Jogja
#
#                                           Description       Category  \
# 84  Taman Pintar Yogyakarta (bahasa Jawa: Hanacara...  Taman Hiburan
# 85  Keraton Ngayogyakarta Hadiningrat atau Keraton...         Budaya
# 86  Sindu Kusuma Edupark (SKE) merupakan sebuah de...  Taman Hiburan
# 87  Museum Benteng Vredeburg (bahasa Jawa: ꦩꦸꦱꦶꦪꦸꦩ...         Budaya
# 88  Museum De Mata merupakan salah satu museum yan...         Budaya
#
#           City  Price  Rating  \
# 84  Yogyakarta   6000     4.5
# 85  Yogyakarta  15000     4.6
# 86  Yogyakarta  20000     4.2
# 87  Yogyakarta   3000     4.6
# 88  Yogyakarta  50000     4.4
#
#                                          Coordinate       Lat        Long
# 84  {'lat': -7.800671500000001, 'lng': 110.3676551} -7.800671  110.367655
# 85          {'lat': -7.8052845, 'lng': 110.3642031} -7.805284  110.364203
# 86  {'lat': -7.767297300000001, 'lng': 110.3542486} -7.767297  110.354249
# 87  {'lat': -7.800201599999999, 'lng': 110.3663044} -7.800202  110.366304
# 88  {'lat': -7.816315599999999, 'lng': 110.3871442} -7.816316  110.387144

# %%
# reset index 

destination_jogja = destination_jogja.reset_index(drop=True)
destination_jogja['IdWisata'] = destination_jogja.index + 1
destination_jogja.head()
# Out:
#    IdWisata                           Place_Name  \
# 0         1              Taman Pintar Yogyakarta
# 1         2                   Keraton Yogyakarta
# 2         3           Sindu Kusuma Edupark (SKE)
# 3         4  Museum Benteng Vredeburg Yogyakarta
# 4         5                 De Mata Museum Jogja
#
#                                          Description       Category  \
# 0  Taman Pintar Yogyakarta (bahasa Jawa: Hanacara...  Taman Hiburan
# 1  Keraton Ngayogyakarta Hadiningrat atau Keraton...         Budaya
# 2  Sindu Kusuma Edupark (SKE) merupakan sebuah de...  Taman Hiburan
# 3  Museum Benteng Vredeburg (bahasa Jawa: ꦩꦸꦱꦶꦪꦸꦩ...         Budaya
# 4  Museum De Mata merupakan salah satu museum yan...         Budaya
#
#          City  Price  Rating                                       Coordinate  \
# 0  Yogyakarta   6000     4.5  {'lat': -7.800671500000001, 'lng': 110.3676551}
# 1  Yogyakarta  15000     4.6          {'lat': -7.8052845, 'lng': 110.3642031}
# 2  Yogyakarta  20000     4.2  {'lat': -7.767297300000001, 'lng': 110.3542486}
# 3  Yogyakarta   3000     4.6  {'lat': -7.800201599999999, 'lng': 110.3663044}
# 4  Yogyakarta  50000     4.4  {'lat': -7.816315599999999, 'lng': 110.3871442}
#
#         Lat        Long
# 0 -7.800671  110.367655
# 1 -7.805284  110.364203
# 2 -7.767297  110.354249
# 3 -7.800202  110.366304
# 4 -7.816316  110.387144

# %%
destination_jogja.tail()
# Out:
#      IdWisata          Place_Name  \
# 121       122    Wisata Kaliurang
# 122       123       Heha Sky View
# 123       124  Taman Sungai Mudal
# 124       125      Pantai Sanglen
# 125       126       Pantai Congot
#
#                                            Description       Category  \
# 121  Jogja selalu menarik untuk dikulik, terlebih t...     Cagar Alam
# 122  HeHa Sky View adalah salah satu tempat wisata ...  Taman Hiburan
# 123  Taman Sungai Mudal, sebuah objek wisata alam t...     Cagar Alam
# 124  Pantai Sanglen. Lokasinya berada di Desa Kemad...         Bahari
# 125  Selain Pantai Glagah dan Pantai Trisik, ternya...         Bahari
#
#            City  Price  Rating  \
# 121  Yogyakarta   8000     4.4
# 122  Yogyakarta  15000     4.4
# 123  Yogyakarta  10000     4.6
# 124  Yogyakarta  10000     4.5
# 125  Yogyakarta   3000     4.3
#
#                                           Coordinate       Lat        Long
# 121          {'lat': -7.6120675, 'lng': 110.4205209} -7.612068  110.420521
# 122           {'lat': -7.8496144, 'lng': 110.478324} -7.849614  110.478324
# 123  {'lat': -7.762813599999998, 'lng': 110.1161626} -7.762814  110.116163
# 124          {'lat': -8.1367456, 'lng': 110.5716362} -8.136746  110.571636
# 125  {'lat': -7.907542500000001, 'lng': 110.0535658} -7.907542  110.053566

# %%
destination_jogja.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 126 entries, 0 to 125
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   IdWisata     126 non-null    int64
#  1   Place_Name   126 non-null    object
#  2   Description  126 non-null    object
#  3   Category     126 non-null    object
#  4   City         126 non-null    object
#  5   Price        126 non-null    int64
#  6   Rating       126 non-null    float64
#  7   Coordinate   126 non-null    object
#  8   Lat          126 non-null    float64
#  9   Long         126 non-null    float64
# dtypes: float64(3), int64(2), object(5)
# memory usage: 10.0+ KB

# %% [markdown]
# <h4> DATA RATING

# %%
rating.head(10)
# Out:
#    IdUser  IdWisata  rating
# 0        1       179              3
# 1        1       344              2
# 2        1         5              5
# 3        1       373              3
# 4        1       101              4
# 5        1       312              2
# 6        1       258              5
# 7        1        20              4
# 8        1       154              2
# 9        1       393              5

# %%
id_jogja = destination_jogja['IdWisata']
ratings_jogja = rating[rating["IdWisata"].isin(id_jogja)]
ratings_jogja = ratings_jogja.reset_index(drop=True)
ratings_jogja.head()
# Out:
#    IdUser  IdWisata  rating
# 0        1         5              5
# 1        1       101              4
# 2        1        20              4
# 3        1       103              3
# 4        1        89              3

# %%
ratings_jogja.tail()
# Out:
#       IdUser  IdWisata  rating
# 2872      300        69              1
# 2873      300         8              1
# 2874      300       108              5
# 2875      300       103              5
# 2876      300        64              4

# %%
ratings_jogja.shape
# Out:
# (2877, 3)

# %% [markdown]
# <h4> DATA USER

# %%
user.head()
# Out:
#    IdUser                   Location  Age
# 0        1      Semarang, Jawa Tengah   20
# 1        2         Bekasi, Jawa Barat   21
# 2        3        Cirebon, Jawa Barat   23
# 3        4         Bekasi, Jawa Barat   21
# 4        5  Lampung, Sumatera Selatan   20

# %%
user.shape
# Out:
# (301, 3)

# %%
id_user = ratings_jogja['IdUser']
user_jogja = user[user['IdUser'].isin(id_user)]
user_jogja = user_jogja.reset_index(drop=True)
user_jogja.head()
# Out:
#    IdUser                   Location  Age
# 0        1      Semarang, Jawa Tengah   20
# 1        2         Bekasi, Jawa Barat   21
# 2        3        Cirebon, Jawa Barat   23
# 3        4         Bekasi, Jawa Barat   21
# 4        5  Lampung, Sumatera Selatan   20

# %%
user_jogja.shape
# Out:
# (300, 3)

# %% [markdown]
# <h1> PREPARE DATA FOR MODELLING

# %%
# Merge with destination_jogja to get category information
df = ratings_jogja.merge(pd.DataFrame(destination_jogja), on='IdWisata')

# Initialize dictionary to store aggregated data
aggregated_data = {}

# Iterate through each row and aggregate ratings
for row in df.itertuples(index=False):
    IdUser = row.IdUser
    category = row.Category
    rating = row.rating
    
    if IdUser not in aggregated_data:
        aggregated_data[IdUser] = {
            'average_category_Bahari': 0.0,
            'average_category_Budaya': 0.0,
            'average_category_Cagar Alam': 0.0,
            'average_category_Pusat Perbelanjaan': 0.0,
            'average_category_Taman Hiburan': 0.0,
            'number_of_ratings_Bahari': 0,
            'number_of_ratings_Budaya': 0,
            'number_of_ratings_Cagar Alam': 0,
            'number_of_ratings_Pusat Perbelanjaan': 0,
            'number_of_ratings_Taman Hiburan': 0,
            'Average_All_Ratings': 0.0
        }
    
    aggregated_data[IdUser]['IdUser'] = IdUser
    aggregated_data[IdUser]['average_category_' + category] += rating
    aggregated_data[IdUser]['number_of_ratings_' + category] += 1
    aggregated_data[IdUser]['Average_All_Ratings'] += rating

# Calculate average ratings and overall average
for IdUser, data in aggregated_data.items():
    for category in ['Bahari', 'Budaya', 'Cagar Alam', 'Pusat Perbelanjaan', 'Taman Hiburan']:
        count = data['number_of_ratings_' + category]
        if count > 0:
            data['average_category_' + category] /= count

    total_ratings = sum(data['number_of_ratings_' + category] for category in ['Bahari', 'Budaya', 'Cagar Alam', 'Pusat Perbelanjaan', 'Taman Hiburan'])
    data['Average_All_Ratings'] /= total_ratings

# Convert aggregated data to DataFrame
pivoted_data = pd.DataFrame.from_dict(aggregated_data, orient='index')

# Reorder columns
columns_order = ['IdUser', 'average_category_Bahari', 'average_category_Budaya', 'average_category_Cagar Alam',
                 'average_category_Pusat Perbelanjaan', 'average_category_Taman Hiburan',
                 'number_of_ratings_Bahari', 'number_of_ratings_Budaya', 'number_of_ratings_Cagar Alam',
                 'number_of_ratings_Pusat Perbelanjaan', 'number_of_ratings_Taman Hiburan', 'Average_All_Ratings']

pivoted_data = pivoted_data[columns_order]

# Display the resulting DataFrame
pivoted_data
# Out:
#      IdUser  average_category_Bahari  average_category_Budaya  \
# 1          1                 3.333333                     3.80
# 4          4                 2.333333                     4.00
# 11        11                 3.333333                     3.75
# 12        12                 4.250000                     5.00
# 35        35                 3.000000                     3.00
# ..       ...                      ...                      ...
# 90        90                 1.000000                     4.00
# 209      209                 2.800000                     4.00
# 191      191                 4.000000                     5.00
# 161      161                 4.000000                     0.00
# 199      199                 3.000000                     3.50
#
#      average_category_Cagar Alam  average_category_Pusat Perbelanjaan  \
# 1                            2.0                                  2.0
# 4                            3.0                                  0.0
# 11                           2.0                                  0.0
# 12                           4.0                                  0.0
# 35                           4.0                                  0.0
# ..                           ...                                  ...
# 90                           2.0                                  0.0
# 209                          0.0                                  0.0
# 191                          2.0                                  0.0
# 161                          1.5                                  0.0
# 199                          4.5                                  0.0
#
#      average_category_Taman Hiburan  number_of_ratings_Bahari  \
# 1                          4.000000                         3
# 4                          3.500000                         3
# 11                         3.333333                         3
# 12                         3.666667                         4
# 35                         0.000000                         2
# ..                              ...                       ...
# 90                         2.250000                         1
# 209                        0.000000                         5
# 191                        2.500000                         1
# 161                        3.857143                         1
# 199                        1.000000                         2
#
#      number_of_ratings_Budaya  number_of_ratings_Cagar Alam  \
# 1                           5                             1
# 4                           4                             1
# 11                          4                             1
# 12                          1                             4
# 35                          2                             2
# ..                        ...                           ...
# 90                          1                             2
# 209                         1                             0
# 191                         1                             1
# 161                         0                             2
# 199                         2                             2
#
#      number_of_ratings_Pusat Perbelanjaan  number_of_ratings_Taman Hiburan  \
# 1                                       1                                1
# 4                                       0                                4
# 11                                      0                                3
# 12                                      0                                6
# 35                                      0                                0
# ..                                    ...                              ...
# 90                                      0                                4
# 209                                     0                                0
# 191                                     0                                2
# 161                                     0                                7
# 199                                     0                                1
#
#      Average_All_Ratings
# 1               3.363636
# 4               3.333333
# 11              3.363636
# 12              4.000000
# 35              3.333333
# ..                   ...
# 90              2.250000
# 209             3.000000
# 191             3.200000
# 161             3.400000
# 199             3.285714
#
# [300 rows x 12 columns]

# %%
pivoted_data
# Out:
#      IdUser  average_category_Bahari  average_category_Budaya  \
# 1          1                 3.333333                     3.80
# 4          4                 2.333333                     4.00
# 11        11                 3.333333                     3.75
# 12        12                 4.250000                     5.00
# 35        35                 3.000000                     3.00
# ..       ...                      ...                      ...
# 90        90                 1.000000                     4.00
# 209      209                 2.800000                     4.00
# 191      191                 4.000000                     5.00
# 161      161                 4.000000                     0.00
# 199      199                 3.000000                     3.50
#
#      average_category_Cagar Alam  average_category_Pusat Perbelanjaan  \
# 1                            2.0                                  2.0
# 4                            3.0                                  0.0
# 11                           2.0                                  0.0
# 12                           4.0                                  0.0
# 35                           4.0                                  0.0
# ..                           ...                                  ...
# 90                           2.0                                  0.0
# 209                          0.0                                  0.0
# 191                          2.0                                  0.0
# 161                          1.5                                  0.0
# 199                          4.5                                  0.0
#
#      average_category_Taman Hiburan  number_of_ratings_Bahari  \
# 1                          4.000000                         3
# 4                          3.500000                         3
# 11                         3.333333                         3
# 12                         3.666667                         4
# 35                         0.000000                         2
# ..                              ...                       ...
# 90                         2.250000                         1
# 209                        0.000000                         5
# 191                        2.500000                         1
# 161                        3.857143                         1
# 199                        1.000000                         2
#
#      number_of_ratings_Budaya  number_of_ratings_Cagar Alam  \
# 1                           5                             1
# 4                           4                             1
# 11                          4                             1
# 12                          1                             4
# 35                          2                             2
# ..                        ...                           ...
# 90                          1                             2
# 209                         1                             0
# 191                         1                             1
# 161                         0                             2
# 199                         2                             2
#
#      number_of_ratings_Pusat Perbelanjaan  number_of_ratings_Taman Hiburan  \
# 1                                       1                                1
# 4                                       0                                4
# 11                                      0                                3
# 12                                      0                                6
# 35                                      0                                0
# ..                                    ...                              ...
# 90                                      0                                4
# 209                                     0                                0
# 191                                     0                                2
# 161                                     0                                7
# 199                                     0                                1
#
#      Average_All_Ratings
# 1               3.363636
# 4               3.333333
# 11              3.363636
# 12              4.000000
# 35              3.333333
# ..                   ...
# 90              2.250000
# 209             3.000000
# 191             3.200000
# 161             3.400000
# 199             3.285714
#
# [300 rows x 12 columns]

# %%
destination_fix = destination_jogja[["IdWisata", "Place_Name", "Category", "Price", "Rating"]]

# Perform one-hot encoding on the "Category" column
category_encoded = pd.get_dummies(destination_fix["Category"], prefix="Category")

# Concatenate the one-hot encoded categories with the selected columns
destination_fix = pd.concat([destination_fix[["IdWisata", "Place_Name", "Price", "Rating"]], category_encoded], axis=1)
destination_fix
# Out:
#      IdWisata                           Place_Name  Price  Rating  \
# 0           1              Taman Pintar Yogyakarta   6000     4.5
# 1           2                   Keraton Yogyakarta  15000     4.6
# 2           3           Sindu Kusuma Edupark (SKE)  20000     4.2
# 3           4  Museum Benteng Vredeburg Yogyakarta   3000     4.6
# 4           5                 De Mata Museum Jogja  50000     4.4
# ..        ...                                  ...    ...     ...
# 121       122                     Wisata Kaliurang   8000     4.4
# 122       123                        Heha Sky View  15000     4.4
# 123       124                   Taman Sungai Mudal  10000     4.6
# 124       125                       Pantai Sanglen  10000     4.5
# 125       126                        Pantai Congot   3000     4.3
#
#      Category_Bahari  Category_Budaya  Category_Cagar Alam  \
# 0                  0                0                    0
# 1                  0                1                    0
# 2                  0                0                    0
# 3                  0                1                    0
# 4                  0                1                    0
# ..               ...              ...                  ...
# 121                0                0                    1
# 122                0                0                    0
# 123                0                0                    1
# 124                1                0                    0
# 125                1                0                    0
#
#      Category_Pusat Perbelanjaan  Category_Taman Hiburan
# 0                              0                       1
# 1                              0                       0
# 2                              0                       1
# 3                              0                       0
# 4                              0                       0
# ..                           ...                     ...
# 121                            0                       0
# 122                            0                       1
# 123                            0                       0
# 124                            0                       0
# 125                            0                       0
#
# [126 rows x 9 columns]

# %%
merged_df = pd.merge(pivoted_data, ratings_jogja, on='IdUser', how='left')

# Merge the destination_fix dataset with the merged pivoted_data and df2 datasets based on 'IdWisata'
final_df = pd.merge(merged_df, destination_fix, on='IdWisata', how='left')
final_df
# Out:
#       IdUser  average_category_Bahari  average_category_Budaya  \
# 0           1                 3.333333                      3.8
# 1           1                 3.333333                      3.8
# 2           1                 3.333333                      3.8
# 3           1                 3.333333                      3.8
# 4           1                 3.333333                      3.8
# ...       ...                      ...                      ...
# 2872      199                 3.000000                      3.5
# 2873      199                 3.000000                      3.5
# 2874      199                 3.000000                      3.5
# 2875      199                 3.000000                      3.5
# 2876      199                 3.000000                      3.5
#
#       average_category_Cagar Alam  average_category_Pusat Perbelanjaan  \
# 0                             2.0                                  2.0
# 1                             2.0                                  2.0
# 2                             2.0                                  2.0
# 3                             2.0                                  2.0
# 4                             2.0                                  2.0
# ...                           ...                                  ...
# 2872                          4.5                                  0.0
# 2873                          4.5                                  0.0
# 2874                          4.5                                  0.0
# 2875                          4.5                                  0.0
# 2876                          4.5                                  0.0
#
#       average_category_Taman Hiburan  number_of_ratings_Bahari  \
# 0                                4.0                         3
# 1                                4.0                         3
# 2                                4.0                         3
# 3                                4.0                         3
# 4                                4.0                         3
# ...                              ...                       ...
# 2872                             1.0                         2
# 2873                             1.0                         2
# 2874                             1.0                         2
# 2875                             1.0                         2
# 2876                             1.0                         2
#
#       number_of_ratings_Budaya  number_of_ratings_Cagar Alam  \
# 0                            5                             1
# 1                            5                             1
# 2                            5                             1
# 3                            5                             1
# 4                            5                             1
# ...                        ...                           ...
# 2872                         2                             2
# 2873                         2                             2
# 2874                         2                             2
# 2875                         2                             2
# 2876                         2                             2
#
#       number_of_ratings_Pusat Perbelanjaan  ...  IdWisata  rating  \
# 0                                        1  ...         5              5
# 1                                        1  ...       101              4
# 2                                        1  ...        20              4
# 3                                        1  ...       103              3
# 4                                        1  ...        89              3
# ...                                    ...  ...       ...            ...
# 2872                                     0  ...        93              3
# 2873                                     0  ...        38              3
# 2874                                     0  ...        73              3
# 2875                                     0  ...        87              4
# 2876                                     0  ...        56              1
#
#                 Place_Name  Price Rating  Category_Bahari  Category_Budaya  \
# 0     De Mata Museum Jogja  50000    4.4                0                1
# 1            Pantai Krakal  10000    4.5                1                0
# 2            Tebing Breksi  20000    4.4                0                1
# 3             Pantai Siung  10000    4.6                1                0
# 4          Pantai Nglambor  10000    4.4                1                0
# ...                    ...    ...    ...              ...              ...
# 2872   Pantai Parangtritis  10000    4.5                1                0
# 2873           Watu Goyang   2500    4.4                0                1
# 2874          Pantai Baron  10000    4.4                1                0
# 2875             Candi Ijo   5000    4.6                0                1
# 2876         Bendung Lepen      0    4.6                0                0
#
#       Category_Cagar Alam  Category_Pusat Perbelanjaan  Category_Taman Hiburan
# 0                       0                            0                       0
# 1                       0                            0                       0
# 2                       0                            0                       0
# 3                       0                            0                       0
# 4                       0                            0                       0
# ...                   ...                          ...                     ...
# 2872                    0                            0                       0
# 2873                    0                            0                       0
# 2874                    0                            0                       0
# 2875                    0                            0                       0
# 2876                    0                            0                       1
#
# [2877 rows x 22 columns]

# %%
full_df = final_df.sample(frac=1).reset_index(drop=True)
full_df
# Out:
#       IdUser  average_category_Bahari  average_category_Budaya  \
# 0         283                 3.500000                 4.666667
# 1         296                 2.000000                 2.750000
# 2         268                 2.250000                 4.000000
# 3         210                 1.000000                 2.666667
# 4         201                 3.000000                 2.000000
# ...       ...                      ...                      ...
# 2872      239                 3.333333                 3.571429
# 2873      146                 2.500000                 1.500000
# 2874      185                 2.333333                 4.333333
# 2875      131                 3.250000                 1.000000
# 2876       15                 3.000000                 3.333333
#
#       average_category_Cagar Alam  average_category_Pusat Perbelanjaan  \
# 0                        4.000000                                  0.0
# 1                        2.000000                                  0.0
# 2                        2.000000                                  0.0
# 3                        3.333333                                  0.0
# 4                        3.000000                                  0.0
# ...                           ...                                  ...
# 2872                     0.000000                                  1.0
# 2873                     4.000000                                  0.0
# 2874                     2.000000                                  5.0
# 2875                     4.000000                                  0.0
# 2876                     4.000000                                  5.0
#
#       average_category_Taman Hiburan  number_of_ratings_Bahari  \
# 0                           3.500000                         4
# 1                           4.000000                         6
# 2                           3.500000                         4
# 3                           3.600000                         2
# 4                           3.333333                         3
# ...                              ...                       ...
# 2872                        3.333333                         3
# 2873                        2.500000                         2
# 2874                        2.200000                         3
# 2875                        2.333333                         4
# 2876                        3.500000                         1
#
#       number_of_ratings_Budaya  number_of_ratings_Cagar Alam  \
# 0                            3                             2
# 1                            4                             1
# 2                            1                             3
# 3                            3                             3
# 4                            1                             3
# ...                        ...                           ...
# 2872                         7                             0
# 2873                         2                             2
# 2874                         3                             1
# 2875                         1                             1
# 2876                         3                             1
#
#       number_of_ratings_Pusat Perbelanjaan  ...  IdWisata  rating  \
# 0                                        0  ...        96              3
# 1                                        0  ...       125              4
# 2                                        0  ...       125              3
# 3                                        0  ...       101              1
# 4                                        0  ...        58              4
# ...                                    ...  ...       ...            ...
# 2872                                     1  ...        92              5
# 2873                                     0  ...        74              3
# 2874                                     1  ...        18              4
# 2875                                     0  ...       113              4
# 2876                                     1  ...        95              3
#
#                     Place_Name  Price Rating  Category_Bahari  \
# 0           Pantai Depok Jogja  10000    4.3                1
# 1               Pantai Sanglen  10000    4.5                1
# 2               Pantai Sanglen  10000    4.5                1
# 3                Pantai Krakal  10000    4.5                1
# 4                  Ledok Sambi      0    4.6                0
# ...                        ...    ...    ...              ...
# 2872      Museum Gunung Merapi  10000    4.4                0
# 2873        Pantai Pok Tunggal  10000    4.5                1
# 2874  Monumen Batik Yogyakarta  40000    4.5                0
# 2875            Pantai Jungwok   5000    4.6                1
# 2876           Candi Ratu Boko  75000    4.6                0
#
#       Category_Budaya  Category_Cagar Alam  Category_Pusat Perbelanjaan  \
# 0                   0                    0                            0
# 1                   0                    0                            0
# 2                   0                    0                            0
# 3                   0                    0                            0
# 4                   0                    1                            0
# ...               ...                  ...                          ...
# 2872                1                    0                            0
# 2873                0                    0                            0
# 2874                1                    0                            0
# 2875                0                    0                            0
# 2876                1                    0                            0
#
#       Category_Taman Hiburan
# 0                          0
# 1                          0
# 2                          0
# 3                          0
# 4                          0
# ...                      ...
# 2872                       0
# 2873                       0
# 2874                       0
# 2875                       0
# 2876                       0
#
# [2877 rows x 22 columns]

# %%
user_full = full_df[['IdUser', 'average_category_Bahari',
       'average_category_Budaya', 'average_category_Cagar Alam',
       'average_category_Pusat Perbelanjaan', 'average_category_Taman Hiburan',
       'number_of_ratings_Bahari', 'number_of_ratings_Budaya',
       'number_of_ratings_Cagar Alam', 'number_of_ratings_Pusat Perbelanjaan',
       'number_of_ratings_Taman Hiburan', 'Average_All_Ratings']]
user_full
# Out:
#       IdUser  average_category_Bahari  average_category_Budaya  \
# 0         283                 3.500000                 4.666667
# 1         296                 2.000000                 2.750000
# 2         268                 2.250000                 4.000000
# 3         210                 1.000000                 2.666667
# 4         201                 3.000000                 2.000000
# ...       ...                      ...                      ...
# 2872      239                 3.333333                 3.571429
# 2873      146                 2.500000                 1.500000
# 2874      185                 2.333333                 4.333333
# 2875      131                 3.250000                 1.000000
# 2876       15                 3.000000                 3.333333
#
#       average_category_Cagar Alam  average_category_Pusat Perbelanjaan  \
# 0                        4.000000                                  0.0
# 1                        2.000000                                  0.0
# 2                        2.000000                                  0.0
# 3                        3.333333                                  0.0
# 4                        3.000000                                  0.0
# ...                           ...                                  ...
# 2872                     0.000000                                  1.0
# 2873                     4.000000                                  0.0
# 2874                     2.000000                                  5.0
# 2875                     4.000000                                  0.0
# 2876                     4.000000                                  5.0
#
#       average_category_Taman Hiburan  number_of_ratings_Bahari  \
# 0                           3.500000                         4
# 1                           4.000000                         6
# 2                           3.500000                         4
# 3                           3.600000                         2
# 4                           3.333333                         3
# ...                              ...                       ...
# 2872                        3.333333                         3
# 2873                        2.500000                         2
# 2874                        2.200000                         3
# 2875                        2.333333                         4
# 2876                        3.500000                         1
#
#       number_of_ratings_Budaya  number_of_ratings_Cagar Alam  \
# 0                            3                             2
# 1                            4                             1
# 2                            1                             3
# 3                            3                             3
# 4                            1                             3
# ...                        ...                           ...
# 2872                         7                             0
# 2873                         2                             2
# 2874                         3                             1
# 2875                         1                             1
# 2876                         3                             1
#
#       number_of_ratings_Pusat Perbelanjaan  number_of_ratings_Taman Hiburan  \
# 0                                        0                                4
# 1                                        0                                2
# 2                                        0                                2
# 3                                        0                                5
# 4                                        0                                3
# ...                                    ...                              ...
# 2872                                     1                                3
# 2873                                     0                                4
# 2874                                     1                                5
# 2875                                     0                                6
# 2876                                     1                                2
#
#       Average_All_Ratings
# 0                3.846154
# 1                2.538462
# 2                2.600000
# 3                2.923077
# 4                3.000000
# ...                   ...
# 2872             3.285714
# 2873             2.600000
# 2874             2.923077
# 2875             2.666667
# 2876             3.625000
#
# [2877 rows x 12 columns]

# %%
item_full = full_df[['IdWisata', 'Price', 'Rating', 'Category_Bahari', 'Category_Budaya', 'Category_Cagar Alam', 
                      'Category_Pusat Perbelanjaan', 'Category_Taman Hiburan']]
item_full
# Out:
#       IdWisata  Price  Rating  Category_Bahari  Category_Budaya  \
# 0           96  10000     4.3                1                0
# 1          125  10000     4.5                1                0
# 2          125  10000     4.5                1                0
# 3          101  10000     4.5                1                0
# 4           58      0     4.6                0                0
# ...        ...    ...     ...              ...              ...
# 2872        92  10000     4.4                0                1
# 2873        74  10000     4.5                1                0
# 2874        18  40000     4.5                0                1
# 2875       113   5000     4.6                1                0
# 2876        95  75000     4.6                0                1
#
#       Category_Cagar Alam  Category_Pusat Perbelanjaan  Category_Taman Hiburan
# 0                       0                            0                       0
# 1                       0                            0                       0
# 2                       0                            0                       0
# 3                       0                            0                       0
# 4                       1                            0                       0
# ...                   ...                          ...                     ...
# 2872                    0                            0                       0
# 2873                    0                            0                       0
# 2874                    0                            0                       0
# 2875                    0                            0                       0
# 2876                    0                            0                       0
#
# [2877 rows x 8 columns]

# %%
y_full = full_df[['rating']]
y_full
# Out:
#       rating
# 0                 3
# 1                 4
# 2                 3
# 3                 1
# 4                 4
# ...             ...
# 2872              5
# 2873              3
# 2874              4
# 2875              4
# 2876              3
#
# [2877 rows x 1 columns]

# %%
item_full_unscaled = item_full
user_full_unscaled = user_full
y_full_unscaled    = y_full

scalerItem = StandardScaler()
scalerItem.fit(item_full)
item_full = scalerItem.transform(item_full)

scalerUser = StandardScaler()
scalerUser.fit(user_full)
user_full = scalerUser.transform(user_full)

scalerTarget = MinMaxScaler((-1, 1))
scalerTarget.fit(y_full.to_numpy().reshape(-1, 1))
y_full = scalerTarget.transform(y_full.to_numpy().reshape(-1, 1))
#ynorm_test = scalerTarget.transform(y_test.reshape(-1, 1))

print(np.allclose(item_full_unscaled, scalerItem.inverse_transform(item_full)))
print(np.allclose(user_full_unscaled, scalerUser.inverse_transform(user_full)))
# Out:
# True
# True

# %%
total_rows = len(y_full)
train_rows = int(0.85 * total_rows)
test_rows = total_rows - train_rows

# %%
user_train = user_full[:train_rows]
user_test = user_full[train_rows:]

item_train = item_full[:train_rows]
item_test = item_full[train_rows:]

y_train = y_full[:train_rows]
y_test = y_full[train_rows:]
print(f"item training data shape: {item_train.shape}")
print(f"item test data shape: {item_test.shape}")

print(f"user training data shape: {user_train.shape}")
print(f"user test data shape: {user_test.shape}")

num_user_features = user_train.shape[1] - 1
num_item_features = item_train.shape[1] - 1

print(f"user test data shape: {num_user_features}")
print(f"item test data shape: {num_item_features}")
# Out:
# item training data shape: (2445, 8)
# item test data shape: (432, 8)
# user training data shape: (2445, 12)
# user test data shape: (432, 12)
# user test data shape: 11
# item test data shape: 7

# %% [markdown]
# <h3>MODELLING

# %%
num_outputs = 16
tf.random.set_seed(1)
user_NN = tf.keras.models.Sequential([    
    tf.keras.layers.Dense(32, activation='relu', name = 'layer1'),
    tf.keras.layers.Dense(16, activation='relu', name = 'layer2'),
    tf.keras.layers.Dense(num_outputs, activation='linear', name = 'layer3')
])

item_NN = tf.keras.models.Sequential([   
    tf.keras.layers.Dense(32, activation='relu', name = 'layer1'),
    tf.keras.layers.Dense(16, activation='relu', name = 'layer2'),
    tf.keras.layers.Dense(num_outputs, activation='linear', name = 'layer3')
])

# create the user input and point to the base network
input_user = tf.keras.layers.Input(shape=(num_user_features))
vu = user_NN(input_user)
vu = tf.linalg.l2_normalize(vu, axis=1)

# create the item input and point to the base network
input_item = tf.keras.layers.Input(shape=(num_item_features))
vm = item_NN(input_item)
vm = tf.linalg.l2_normalize(vm, axis=1)

# compute the dot product of the two vectors vu and vm
output = tf.keras.layers.Dot(axes=1)([vu, vm])

# specify the inputs and output of the model
model = tf.keras.Model([input_user, input_item], output)

model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 11)]         0
# __________________________________________________________________________________________________
# input_2 (InputLayer)            [(None, 7)]          0
# __________________________________________________________________________________________________
# sequential (Sequential)         (None, 16)           1184        input_1[0][0]
# __________________________________________________________________________________________________
# sequential_1 (Sequential)       (None, 16)           1056        input_2[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Square (TensorFlowO [(None, 16)]         0           sequential[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Square_1 (TensorFlo [(None, 16)]         0           sequential_1[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Sum (TensorFlowOpLa [(None, 1)]          0           tf_op_layer_Square[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Sum_1 (TensorFlowOp [(None, 1)]          0           tf_op_layer_Square_1[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Maximum (TensorFlow [(None, 1)]          0           tf_op_layer_Sum[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Maximum_1 (TensorFl [(None, 1)]          0           tf_op_layer_Sum_1[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Rsqrt (TensorFlowOp [(None, 1)]          0           tf_op_layer_Maximum[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Rsqrt_1 (TensorFlow [(None, 1)]          0           tf_op_layer_Maximum_1[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Mul (TensorFlowOpLa [(None, 16)]         0           sequential[0][0]
#                                                                  tf_op_layer_Rsqrt[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Mul_1 (TensorFlowOp [(None, 16)]         0           sequential_1[0][0]
#                                                                  tf_op_layer_Rsqrt_1[0][0]
# __________________________________________________________________________________________________
# dot (Dot)                       (None, 1)            0           tf_op_layer_Mul[0][0]
#                                                                  tf_op_layer_Mul_1[0][0]
# ==================================================================================================
# Total params: 2,240
# Trainable params: 2,240
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
tf.random.set_seed(1)
cost_fn = tf.keras.losses.MeanSquaredError()
opt = keras.optimizers.Adam(learning_rate=0.001)
model.compile(optimizer=opt,
              loss=cost_fn)
# model.compile(loss = tf.keras.losses.MeanSquaredError(),
#     optimizer = tf.keras.optimizers.RMSprop(learning_rate=0.002),
#     metrics=[tf.keras.metrics.RootMeanSquaredError()]
#     )

# %%
tf.random.set_seed(1)
model.fit([user_train[:, 1:], item_train[:,1:]], y_train, epochs=20)
# Out:
# Epoch 1/20
# 77/77 [==============================] - 0s 3ms/step - loss: 0.4557
# Epoch 2/20
# 77/77 [==============================] - 0s 3ms/step - loss: 0.4210
# Epoch 3/20
# 77/77 [==============================] - 0s 4ms/step - loss: 0.4020
# Epoch 4/20
# 77/77 [==============================] - 0s 3ms/step - loss: 0.3830
# Epoch 5/20
# 77/77 [==============================] - 0s 4ms/step - loss: 0.3695
# Epoch 6/20
# 77/77 [==============================] - 0s 3ms/step - loss: 0.3559
# Epoch 7/20
# 77/77 [==============================] - 0s 4ms/step - loss: 0.3446
# Epoch 8/20
# 77/77 [==============================] - 0s 3ms/step - loss: 0.3389
# Epoch 9/20
# 77/77 [==============================] - 0s 4ms/step - loss: 0.3328
# Epoch 10/20
# 77/77 [==============================] - 0s 3ms/step - loss: 0.3305
# Epoch 11/20
# 77/77 [==============================] - 0s 3ms/step - loss: 0.3253
# Epoch 12/20
# 77/77 [==============================] - 0s 3ms/step - loss: 0.3228
# Epoch 13/20
# 77/77 [==============================] - 0s 3ms/step - loss: 0.3191
# Epoch 14/20
# 77/77 [==============================] - 0s 3ms/step - loss: 0.3177
# Epoch 15/20
# 77/77 [==============================] - 0s 3ms/step - loss: 0.3158
# Epoch 16/20
# 77/77 [==============================] - 0s 3ms/step - loss: 0.3142
# Epoch 17/20
# 77/77 [==============================] - 0s 3ms/step - loss: 0.3135
# Epoch 18/20
# 77/77 [==============================] - 0s 4ms/step - loss: 0.3113
# Epoch 19/20
# 77/77 [==============================] - 0s 3ms/step - loss: 0.3093
# Epoch 20/20
# 77/77 [==============================] - 0s 3ms/step - loss: 0.3086

# %%
model.evaluate([user_test[:, 1:], item_test[:, 1:]], y_test)
# Out:
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3802
# 0.38019058108329773

# %% [markdown]
# <h2> COBA_COBA PREDICT

# %%
data = {
    'IdUser': [400, 400, 400, 400, 400, 400, 400, 400, 400, 400, 400, 400, 400, 400, 400, 400, 400],
    'IdWisata': [154, 209, 113, 149, 210, 85, 87, 207, 152, 153, 95, 103, 115, 118, 100, 179, 105],
    'rating': [3, 4, 2, 3, 4, 5, 4, 5, 4, 5, 4, 4, 5, 5, 5, 5, 5]
}

df_pred = pd.DataFrame(data)
print(df_pred)
# Out:
#     IdUser  IdWisata  rating
# 0       400       154              3
# 1       400       209              4
# 2       400       113              2
# 3       400       149              3
# 4       400       210              4
# 5       400        85              5
# 6       400        87              4
# 7       400       207              5
# 8       400       152              4
# 9       400       153              5
# 10      400        95              4
# 11      400       103              4
# 12      400       115              5
# 13      400       118              5
# 14      400       100              5
# 15      400       179              5
# 16      400       105              5

# %%
def calculate_user_ratings(ratings_jogja, destination_jogja=destination_jogja):
    # Merge with destination_jogja to get category information
    df = ratings_jogja.merge(pd.DataFrame(destination_jogja), on='IdWisata')

    # Initialize dictionary to store aggregated data
    aggregated_data = {}

    # Iterate through each row and aggregate ratings
    for row in df.itertuples(index=False):
        IdUser = row.IdUser
        category = row.Category
        rating = row.rating

        if IdUser not in aggregated_data:
            aggregated_data[IdUser] = {
                'average_category_Bahari': 0.0,
                'average_category_Budaya': 0.0,
                'average_category_Cagar Alam': 0.0,
                'average_category_Pusat Perbelanjaan': 0.0,
                'average_category_Taman Hiburan': 0.0,
                'number_of_ratings_Bahari': 0,
                'number_of_ratings_Budaya': 0,
                'number_of_ratings_Cagar Alam': 0,
                'number_of_ratings_Pusat Perbelanjaan': 0,
                'number_of_ratings_Taman Hiburan': 0,
                'Average_All_Ratings': 0.0
            }

        aggregated_data[IdUser]['IdUser'] = IdUser
        aggregated_data[IdUser]['average_category_' + category] += rating
        aggregated_data[IdUser]['number_of_ratings_' + category] += 1
        aggregated_data[IdUser]['Average_All_Ratings'] += rating

    # Calculate average ratings and overall average
    for IdUser, data in aggregated_data.items():
        for category in ['Bahari', 'Budaya', 'Cagar Alam', 'Pusat Perbelanjaan', 'Taman Hiburan']:
            count = data['number_of_ratings_' + category]
            if count > 0:
                data['average_category_' + category] /= count

        total_ratings = sum(data['number_of_ratings_' + category] for category in ['Bahari', 'Budaya', 'Cagar Alam', 'Pusat Perbelanjaan', 'Taman Hiburan'])
        data['Average_All_Ratings'] /= total_ratings

    # Convert aggregated data to DataFrame
    pivoted_data = pd.DataFrame.from_dict(aggregated_data, orient='index')

    # Reorder columns
    columns_order = ['IdUser', 'average_category_Bahari', 'average_category_Budaya', 'average_category_Cagar Alam',
                     'average_category_Pusat Perbelanjaan', 'average_category_Taman Hiburan',
                     'number_of_ratings_Bahari', 'number_of_ratings_Budaya', 'number_of_ratings_Cagar Alam',
                     'number_of_ratings_Pusat Perbelanjaan', 'number_of_ratings_Taman Hiburan', 'Average_All_Ratings']

    pivoted_data = pivoted_data[columns_order]

    # Display the resulting DataFrame
    return pivoted_data

# %%
user_vec = calculate_user_ratings(df_pred, destination_jogja=destination_jogja)
user_vec
# Out:
#      IdUser  average_category_Bahari  average_category_Budaya  \
# 400      400                 4.333333                      4.0
#
#      average_category_Cagar Alam  average_category_Pusat Perbelanjaan  \
# 400                          5.0                                  0.0
#
#      average_category_Taman Hiburan  number_of_ratings_Bahari  \
# 400                             0.0                         6
#
#      number_of_ratings_Budaya  number_of_ratings_Cagar Alam  \
# 400                         2                             1
#
#      number_of_ratings_Pusat Perbelanjaan  number_of_ratings_Taman Hiburan  \
# 400                                     0                                0
#
#      Average_All_Ratings
# 400             4.333333

# %%
user_vecs = np.tile(user_vec, (len(destination_fix), 1))
user_vecs
# Out:
# array([[400.        ,   4.33333333,   4.        , ...,   0.        ,
#           0.        ,   4.33333333],
#        [400.        ,   4.33333333,   4.        , ...,   0.        ,
#           0.        ,   4.33333333],
#        [400.        ,   4.33333333,   4.        , ...,   0.        ,
#           0.        ,   4.33333333],
#        ...,
#        [400.        ,   4.33333333,   4.        , ...,   0.        ,
#           0.        ,   4.33333333],
#        [400.        ,   4.33333333,   4.        , ...,   0.        ,
#           0.        ,   4.33333333],
#        [400.        ,   4.33333333,   4.        , ...,   0.        ,
#           0.        ,   4.33333333]])

# %%
user_vec = calculate_user_ratings(df_pred, destination_jogja)
user_vec
# Out:
#      IdUser  average_category_Bahari  average_category_Budaya  \
# 400      400                 4.333333                      4.0
#
#      average_category_Cagar Alam  average_category_Pusat Perbelanjaan  \
# 400                          5.0                                  0.0
#
#      average_category_Taman Hiburan  number_of_ratings_Bahari  \
# 400                             0.0                         6
#
#      number_of_ratings_Budaya  number_of_ratings_Cagar Alam  \
# 400                         2                             1
#
#      number_of_ratings_Pusat Perbelanjaan  number_of_ratings_Taman Hiburan  \
# 400                                     0                                0
#
#      Average_All_Ratings
# 400             4.333333

# %%
item_vecs = destination_fix.drop('Place_Name', axis=1)
item_vecs
# Out:
#      IdWisata  Price  Rating  Category_Bahari  Category_Budaya  \
# 0           1   6000     4.5                0                0
# 1           2  15000     4.6                0                1
# 2           3  20000     4.2                0                0
# 3           4   3000     4.6                0                1
# 4           5  50000     4.4                0                1
# ..        ...    ...     ...              ...              ...
# 121       122   8000     4.4                0                0
# 122       123  15000     4.4                0                0
# 123       124  10000     4.6                0                0
# 124       125  10000     4.5                1                0
# 125       126   3000     4.3                1                0
#
#      Category_Cagar Alam  Category_Pusat Perbelanjaan  Category_Taman Hiburan
# 0                      0                            0                       1
# 1                      0                            0                       0
# 2                      0                            0                       1
# 3                      0                            0                       0
# 4                      0                            0                       0
# ..                   ...                          ...                     ...
# 121                    1                            0                       0
# 122                    0                            0                       1
# 123                    1                            0                       0
# 124                    0                            0                       0
# 125                    0                            0                       0
#
# [126 rows x 8 columns]

# %%
# scale our user and item vectors
suser_vecs = scalerUser.transform(user_vecs)
sitem_vecs = scalerItem.transform(item_vecs)


# make a prediction
y_p = model.predict([suser_vecs[:, 1:], sitem_vecs[:, 1:]])
# # unscale y prediction 
y_pu = scalerTarget.inverse_transform(y_p)
y_pu

# sort the results, highest prediction first
sorted_index = np.argsort(-y_pu,axis=0).reshape(-1).tolist()  #negate to get largest rating first
sorted_ypu   = y_pu[sorted_index]
sorted_index = [x+0 for x in sorted_index]
sorted_items = item_vecs.loc[sorted_index]  #using unscaled vectors for display
sorted_items
# print_pred_movies(sorted_ypu, sorted_items, movie_dict, maxcount = 10)
# Out:
# /home/abdulhafidh/anaconda3/envs/tf210/lib/python3.7/site-packages/sklearn/base.py:451: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   "X does not have valid feature names, but"
#      IdWisata  Price  Rating  Category_Bahari  Category_Budaya  \
# 79         80   2500     4.4                0                0
# 64         65   3000     4.4                0                0
# 121       122   8000     4.4                0                0
# 82         83      0     4.5                0                0
# 74         75   2500     4.5                0                0
# ..        ...    ...     ...              ...              ...
# 6           7      0     4.4                0                0
# 119       120      0     4.4                0                0
# 7           8      0     4.7                0                0
# 18         19      0     4.7                0                0
# 21         22      0     4.8                0                0
#
#      Category_Cagar Alam  Category_Pusat Perbelanjaan  Category_Taman Hiburan
# 79                     1                            0                       0
# 64                     1                            0                       0
# 121                    1                            0                       0
# 82                     1                            0                       0
# 74                     1                            0                       0
# ..                   ...                          ...                     ...
# 6                      0                            0                       1
# 119                    0                            0                       1
# 7                      0                            0                       1
# 18                     0                            0                       1
# 21                     0                            0                       1
#
# [126 rows x 8 columns]

# %%
def print_prediction(sorted_items, sorted_ypu, num_recommend, destination_jogja=destination_jogja):
    res = pd.merge(sorted_items[['IdWisata']], destination_jogja[["IdWisata", "Place_Name", "Category", "Rating"]], on="IdWisata")[:num_recommend]
    res["Predict_Rating"] = sorted_ypu[:num_recommend]
    return res

# %%
print_prediction(sorted_items, sorted_ypu, 40, destination_jogja=destination_jogja)
# Out:
#     IdWisata                             Place_Name    Category  Rating  \
# 0         80                  Pintoe Langit Dahromo  Cagar Alam     4.4
# 1         65                              Goa Cerme  Cagar Alam     4.4
# 2        122                       Wisata Kaliurang  Cagar Alam     4.4
# 3         83          Geoforest Watu Payung Turunan  Cagar Alam     4.5
# 4         75                       Hutan Pinus Asri  Cagar Alam     4.5
# 5         79                    Watu Mabur Mangunan  Cagar Alam     4.5
# 6         57                 Bunker Kaliadem Merapi  Cagar Alam     4.5
# 7         82                     Kebun Teh Nglinggo  Cagar Alam     4.5
# 8         62                Bukit Wisata Pulepayung  Cagar Alam     4.5
# 9        108                  Air Terjun Sri Gethuk  Cagar Alam     4.4
# 10        53                   Wisata Alam Kalibiru  Cagar Alam     4.4
# 11        48                Air Terjun Kedung Pedut  Cagar Alam     4.5
# 12        47                           Watu Lumbung  Cagar Alam     4.3
# 13        64                    Goa Rancang Kencono  Cagar Alam     4.3
# 14        94                             Goa Pindul  Cagar Alam     4.5
# 15         9                       Gembira Loka Zoo  Cagar Alam     4.5
# 16       124                     Taman Sungai Mudal  Cagar Alam     4.6
# 17        59              Seribu Batu Songgo Langit  Cagar Alam     4.6
# 18        58                            Ledok Sambi  Cagar Alam     4.6
# 19        85                          Puncak Segoro  Cagar Alam     4.2
# 20        60                           Goa Jomblang  Cagar Alam     4.6
# 21        84                          Pantai Timang      Bahari     4.7
# 22        55  Puncak Gunung Api Purba - Nglanggeran  Cagar Alam     4.7
# 23        77            Bukit Paralayang, Watugupit  Cagar Alam     4.7
# 24       104                        Pantai Sadranan      Bahari     4.6
# 25       103                           Pantai Siung      Bahari     4.6
# 26       113                         Pantai Jungwok      Bahari     4.6
# 27       114                         Pantai Greweng      Bahari     4.6
# 28       116                      Pantai Watu Kodok      Bahari     4.6
# 29       117                         Pantai Kesirat      Bahari     4.6
# 30        71                        Pantai Ngobaran      Bahari     4.6
# 31        70                  Pantai Ngrawe (Mesra)      Bahari     4.5
# 32       125                         Pantai Sanglen      Bahari     4.5
# 33        93                    Pantai Parangtritis      Bahari     4.5
# 34        74                     Pantai Pok Tunggal      Bahari     4.5
# 35       101                          Pantai Krakal      Bahari     4.5
# 36       118                        Pantai Ngandong      Bahari     4.5
# 37        88                      Pantai Indrayanti      Bahari     4.5
# 38        72                    Pantai Pulang Sawal      Bahari     4.5
# 39       107                           Pantai Drini      Bahari     4.5
#
#     Predict_Rating
# 0         4.244456
# 1         4.243488
# 2         4.233366
# 3         4.227782
# 4         4.226241
# 5         4.226241
# 6         4.226085
# 7         4.224787
# 8         4.222111
# 9         4.220805
# 10        4.211846
# 11        4.210524
# 12        4.189895
# 13        4.189895
# 14        4.170560
# 15        4.113385
# 16        4.109486
# 17        4.096364
# 18        4.092379
# 19        4.087604
# 20        3.949397
# 21        3.930940
# 22        3.874005
# 23        3.859569
# 24        3.828386
# 25        3.828386
# 26        3.783203
# 27        3.783203
# 28        3.783203
# 29        3.783203
# 30        3.783203
# 31        3.715565
# 32        3.715565
# 33        3.715565
# 34        3.715565
# 35        3.715565
# 36        3.715565
# 37        3.715565
# 38        3.715565
# 39        3.715565

# %% [markdown]
# # Convert Model To TFLITE

# %%
# convert model to tflite

# Convert the model to the TensorFlow Lite format with quantization

converter = tf.lite.TFLiteConverter.from_keras_model(model)

converter.optimizations = [tf.lite.Optimize.OPTIMIZE_FOR_SIZE]

tflite_model = converter.convert()

# Save the model to disk

open("Recommender_Model.tflite", "wb").write(tflite_model)
# Out:
# 2023-06-09 14:20:31.825985: I tensorflow/core/grappler/devices.cc:55] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0
# 2023-06-09 14:20:31.826296: I tensorflow/core/grappler/clusters/single_machine.cc:356] Starting new session
# 2023-06-09 14:20:31.832492: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:797] Optimization results for grappler item: graph_to_optimize
# 2023-06-09 14:20:31.832552: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:799]   function_optimizer: function_optimizer did nothing. time = 0.005ms.
# 2023-06-09 14:20:31.832565: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:799]   function_optimizer: function_optimizer did nothing. time = 0.005ms.
# 2023-06-09 14:20:31.994650: I tensorflow/core/grappler/devices.cc:55] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0
# 2023-06-09 14:20:31.994935: I tensorflow/core/grappler/clusters/single_machine.cc:356] Starting new session
# 2023-06-09 14:20:32.009619: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:797] Optimization results for grappler item: graph_to_optimize
# 2023-06-09 14:20:32.009687: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:799]   constant_folding: Graph size after: 51 nodes (-13), 52 edges (-13), time = 6.495ms.
# 2023-06-09 14:20:32.009701: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:799]   constant_folding: Graph size after: 51 nodes (0), 52 edges (0), time = 2.607ms.
# 14784

# %%
# convert model to h5

model.save('Recommender_Model.h5')

# %%
# load model h5

import json
import tensorflow as tf

model_tes = tf.keras.models.load_model('Recommender_Model.h5')

# test the model with this data

new_data = {
    'IdUser': [1, 1, 1, 1, 1,1,1],
    'IdWisata': [1, 5, 3, 5, 4,4,4],
    'rating': [5, 5, 5, 3, 3,2,2]
}

df_pred = pd.DataFrame(new_data)

user_vec = calculate_user_ratings(df_pred, destination_jogja=destination_jogja)

user_vecs = np.tile(user_vec, (len(destination_fix), 1))

user_vec = calculate_user_ratings(df_pred, destination_jogja)

item_vecs = destination_fix.drop('Place_Name', axis=1)

# scale our user and item vectors

suser_vecs = scalerUser.transform(user_vecs)

sitem_vecs = scalerItem.transform(item_vecs)

# make a prediction

y_p = model_tes.predict([suser_vecs[:, 1:], sitem_vecs[:, 1:]])

# unscale y prediction

y_pu = scalerTarget.inverse_transform(y_p)

# sort the results, highest prediction first

sorted_index = np.argsort(-y_pu,axis=0).reshape(-1).tolist()  #negate to get largest rating first

sorted_ypu   = y_pu[sorted_index]

sorted_index = [x+0 for x in sorted_index]

sorted_items = item_vecs.loc[sorted_index]  #using unscaled vectors for display

# IdWisata value from sorted_items put on json file

IdWisata = sorted_items['IdWisata'].values.tolist()

# convert to json

json_str = json.dumps(IdWisata)

# convert to dict

json_dict = json.loads(json_str)

# write to json file

with open('IdWisata.json', 'w') as json_file:

    json.dump(json_dict, json_file)





print_prediction(sorted_items, sorted_ypu, 126, destination_jogja=destination_jogja)
# Out:
# /home/abdulhafidh/anaconda3/envs/tf210/lib/python3.7/site-packages/sklearn/base.py:451: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   "X does not have valid feature names, but"
#      IdWisata                     Place_Name       Category  Rating  \
# 0           8     Nol Kilometer Jl.Malioboro  Taman Hiburan     4.7
# 1          19           Tugu Pal Putih Jogja  Taman Hiburan     4.7
# 2          22              Kawasan Malioboro  Taman Hiburan     4.8
# 3          56                  Bendung Lepen  Taman Hiburan     4.6
# 4          12   Alun Alun Selatan Yogyakarta  Taman Hiburan     4.6
# ..        ...                            ...            ...     ...
# 121        79            Watu Mabur Mangunan     Cagar Alam     4.5
# 122        83  Geoforest Watu Payung Turunan     Cagar Alam     4.5
# 123        58                    Ledok Sambi     Cagar Alam     4.6
# 124        59      Seribu Batu Songgo Langit     Cagar Alam     4.6
# 125       124             Taman Sungai Mudal     Cagar Alam     4.6
#
#      Predict_Rating
# 0          4.016990
# 1          4.016990
# 2          3.972672
# 3          3.957180
# 4          3.957180
# ..              ...
# 121        1.805762
# 122        1.804029
# 123        1.791189
# 124        1.788073
# 125        1.778746
#
# [126 rows x 5 columns]

# %%
# # print_prediction based on tflite model

# # Load the TFLite model and allocate tensors.

# interpreter = tf.lite.Interpreter(model_path="Recommender_Model.tflite")

# interpreter.allocate_tensors()

# # Get input and output tensors.

# input_details = interpreter.get_input_details()

# output_details = interpreter.get_output_details()


# # test the model with this data

# new_data = {
#     'IdUser': [1, 1, 1, 1, 1],
#     'IdWisata': [1, 2, 3, 4, 5],
#     'rating': [5, 5, 5, 3, 3]
# }

# new_data = pd.DataFrame(new_data)

# user_vec = calculate_user_ratings(new_data, destination_jogja=destination_jogja)

# user_vecs = np.tile(user_vec, (len(destination_fix), 1))

# user_vec = calculate_user_ratings(new_data, destination_jogja)

# item_vecs = destination_fix.drop('Place_Name', axis=1)

# # scale our user and item vectors

# suser_vecs = scalerUser.transform(user_vecs)

# sitem_vecs = scalerItem.transform(item_vecs)

# # make a prediction

# print(suser_vecs)

# print(sitem_vecs)

# # convert to array 

# print("array")

# suser_vecs = np.array(suser_vecs, dtype=np.float32)

# sitem_vecs = np.array(sitem_vecs, dtype=np.float32)

# print(suser_vecs)

# print(sitem_vecs)


# interpreter.invoke()

# y_p = interpreter.get_tensor(output_details[0]['index'])

# # unscale y prediction

# y_pu = scalerTarget.inverse_transform(y_p)

# # sort the results, highest prediction first

# sorted_index = np.argsort(-y_pu,axis=0).reshape(-1).tolist()  #negate to get largest rating first

# sorted_ypu   = y_pu[sorted_index]

# sorted_index = [x+0 for x in sorted_index]

# sorted_items = item_vecs.loc[sorted_index]  #using unscaled vectors for display

# print_prediction(sorted_items, sorted_ypu, 40, destination_jogja=destination_jogja)
